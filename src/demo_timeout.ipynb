# %%
import sys, os

MARIPOSA_PATH = "/home/yizhou7/mariposa/"

sys.path.append(MARIPOSA_PATH + "src")
os.chdir(MARIPOSA_PATH)

from debugger.debugger import DbgMode
from debugger.bench_viewer import BenchViewer
from debugger.strainer import StrainerStatus
from benchmark_consts import *

# %%
mv = BenchViewer(TIMEOUT_TARGETS, DbgMode.TIMEOUT)

# %%
mv.status.print_status()
# Out:
# | category                   |   count | percentage   |
# |----------------------------|---------|--------------|
# | StrainerStatus.NOT_CREATED |     438 | 98.65 %      |
# | StrainerStatus.NOT_TESTED  |       4 | 0.9 %        |
# | StrainerStatus.FINISHED    |       1 | 0.23 %       |
# | StrainerStatus.UNFILTERED  |       1 | 0.23 %       |
# | total                      |     444 | 100.00 %     |

# %%
print(len(mv.fixable))
print(len(mv.fixable)/len(mv.status[StrainerStatus.FINISHED]))
# Out:
# 1
# 1.0

# %%
for q in mv.status[StrainerStatus.NOT_CREATED]:
    print("./src/debugger3.py -m timeout -i", mv[q].name_hash, "--create-project")
# Out:
# ./src/debugger3.py -m timeout -i 7fd5899ce2 --create-project
# ./src/debugger3.py -m timeout -i e93855aadd --create-project
# ./src/debugger3.py -m timeout -i 3ab530aac4 --create-project
# ./src/debugger3.py -m timeout -i c066e22df7 --create-project
# ./src/debugger3.py -m timeout -i 16e535bb0c --create-project
# ./src/debugger3.py -m timeout -i 8e8d83f571 --create-project
# ./src/debugger3.py -m timeout -i 19e7b4a644 --create-project
# ./src/debugger3.py -m timeout -i 0ef92feb14 --create-project
# ./src/debugger3.py -m timeout -i 0897ef84da --create-project
# ./src/debugger3.py -m timeout -i 38d93c5774 --create-project
# ./src/debugger3.py -m timeout -i cc1d9c148f --create-project
# ./src/debugger3.py -m timeout -i ff4c3e8cab --create-project
# ./src/debugger3.py -m timeout -i e9080f3e47 --create-project
# ./src/debugger3.py -m timeout -i 30af6a3633 --create-project
# ./src/debugger3.py -m timeout -i 297c8f2526 --create-project
# ./src/debugger3.py -m timeout -i b5b0f8c2f2 --create-project
# ./src/debugger3.py -m timeout -i 630625681a --create-project
# ./src/debugger3.py -m timeout -i 613f2c355d --create-project
# ./src/debugger3.py -m timeout -i 1f1391e20c --create-project
# ./src/debugger3.py -m timeout -i cdfc45fd41 --create-project
# ./src/debugger3.py -m timeout -i 72139a143b --create-project
# ./src/debugger3.py -m timeout -i 7e3368fab1 --create-project
# ./src/debugger3.py -m timeout -i 6884529c21 --create-project
# ./src/debugger3.py -m timeout -i 83c57f0bcb --create-project
# ./src/debugger3.py -m timeout -i 72d4708532 --create-project
# ./src/debugger3.py -m timeout -i 9967bcf803 --create-project
# ./src/debugger3.py -m timeout -i 740fdc77a1 --create-project
# ./src/debugger3.py -m timeout -i 7b0fbd9a55 --create-project
# ./src/debugger3.py -m timeout -i 8a59d4481f --create-project
# ./src/debugger3.py -m timeout -i 02ce0894ca --create-project
# ./src/debugger3.py -m timeout -i 6b83ccf507 --create-project
# ./src/debugger3.py -m timeout -i adf9eda1ef --create-project
# ./src/debugger3.py -m timeout -i 1673ca97a5 --create-project
# ./src/debugger3.py -m timeout -i 28b317196a --create-project
# ./src/debugger3.py -m timeout -i 34eda2f999 --create-project
# ./src/debugger3.py -m timeout -i 6f6c55d971 --create-project
# ./src/debugger3.py -m timeout -i 2cbf19182c --create-project
# ./src/debugger3.py -m timeout -i 9825043af6 --create-project
# ./src/debugger3.py -m timeout -i 0cfa69df01 --create-project
# ./src/debugger3.py -m timeout -i f6fde2cf65 --create-project
# ./src/debugger3.py -m timeout -i 68aa54b124 --create-project
# ./src/debugger3.py -m timeout -i 3c3d86031e --create-project
# ./src/debugger3.py -m timeout -i 2ba7cc6a6a --create-project
# ./src/debugger3.py -m timeout -i e1c4753770 --create-project
# ./src/debugger3.py -m timeout -i 8031fd6ec8 --create-project
# ./src/debugger3.py -m timeout -i b6e82319b9 --create-project
# ./src/debugger3.py -m timeout -i e41d0ee45e --create-project
# ./src/debugger3.py -m timeout -i 1d32c4d524 --create-project
# ./src/debugger3.py -m timeout -i ef1ebd5d7d --create-project
# ./src/debugger3.py -m timeout -i 9af86b2cd6 --create-project
# ./src/debugger3.py -m timeout -i 5af6d28737 --create-project
# ./src/debugger3.py -m timeout -i 11e4bbf583 --create-project
# ./src/debugger3.py -m timeout -i 60095b1a59 --create-project
# ./src/debugger3.py -m timeout -i 1ab6690346 --create-project
# ./src/debugger3.py -m timeout -i 3b1c756824 --create-project
# ./src/debugger3.py -m timeout -i de06634d5d --create-project
# ./src/debugger3.py -m timeout -i bfa5905941 --create-project
# ./src/debugger3.py -m timeout -i 667b2b80fe --create-project
# ./src/debugger3.py -m timeout -i 1996525606 --create-project
# ./src/debugger3.py -m timeout -i 81f604e545 --create-project
# ./src/debugger3.py -m timeout -i e5c19b8ea5 --create-project
# ./src/debugger3.py -m timeout -i 7eea650229 --create-project
# ./src/debugger3.py -m timeout -i 1c02a6059f --create-project
# ./src/debugger3.py -m timeout -i f5d478ae5f --create-project
# ./src/debugger3.py -m timeout -i 0defc27a3b --create-project
# ./src/debugger3.py -m timeout -i b9896cbaf6 --create-project
# ./src/debugger3.py -m timeout -i 5fbd6f43b7 --create-project
# ./src/debugger3.py -m timeout -i 738511822f --create-project
# ./src/debugger3.py -m timeout -i 4040d2a20b --create-project
# ./src/debugger3.py -m timeout -i e65b46b51f --create-project
# ./src/debugger3.py -m timeout -i b8ed14e0c5 --create-project
# ./src/debugger3.py -m timeout -i f335e72a88 --create-project
# ./src/debugger3.py -m timeout -i 0c40f30097 --create-project
# ./src/debugger3.py -m timeout -i c97090bb09 --create-project
# ./src/debugger3.py -m timeout -i 50e9564b05 --create-project
# ./src/debugger3.py -m timeout -i a9ba4f3553 --create-project
# ./src/debugger3.py -m timeout -i 243ec915e0 --create-project
# ./src/debugger3.py -m timeout -i db5b85130e --create-project
# ./src/debugger3.py -m timeout -i f81ecefbe1 --create-project
# ./src/debugger3.py -m timeout -i 00d9c7f438 --create-project
# ./src/debugger3.py -m timeout -i 0c00bb9db6 --create-project
# ./src/debugger3.py -m timeout -i 22bc3230fa --create-project
# ./src/debugger3.py -m timeout -i 9f41cf9dd5 --create-project
# ./src/debugger3.py -m timeout -i bf6d57d525 --create-project
# ./src/debugger3.py -m timeout -i 70d34357b4 --create-project
# ./src/debugger3.py -m timeout -i 1d23e345a5 --create-project
# ./src/debugger3.py -m timeout -i 4f68aa20b3 --create-project
# ./src/debugger3.py -m timeout -i b546a78766 --create-project
# ./src/debugger3.py -m timeout -i 02378bfc2b --create-project
# ./src/debugger3.py -m timeout -i b8265691e7 --create-project
# ./src/debugger3.py -m timeout -i fbd113c34b --create-project
# ./src/debugger3.py -m timeout -i 3ac32afb30 --create-project
# ./src/debugger3.py -m timeout -i d347f45fa2 --create-project
# ./src/debugger3.py -m timeout -i caebe30494 --create-project
# ./src/debugger3.py -m timeout -i 5e2368e7d9 --create-project
# ./src/debugger3.py -m timeout -i 31e9d7c601 --create-project
# ./src/debugger3.py -m timeout -i 0416307c14 --create-project
# ./src/debugger3.py -m timeout -i 422a6c0817 --create-project
# ./src/debugger3.py -m timeout -i eec60fd21e --create-project
# ./src/debugger3.py -m timeout -i 1de7054a37 --create-project
# ./src/debugger3.py -m timeout -i 041773ee5b --create-project
# ./src/debugger3.py -m timeout -i 09e4f9c085 --create-project
# ./src/debugger3.py -m timeout -i 31258859ac --create-project
# ./src/debugger3.py -m timeout -i 782b28a40e --create-project
# ./src/debugger3.py -m timeout -i c4350a29e0 --create-project
# ./src/debugger3.py -m timeout -i 7af5ba0b16 --create-project
# ./src/debugger3.py -m timeout -i 3a37e843fb --create-project
# ./src/debugger3.py -m timeout -i 11435d7e73 --create-project
# ./src/debugger3.py -m timeout -i ab13d91431 --create-project
# ./src/debugger3.py -m timeout -i 57ff707219 --create-project
# ./src/debugger3.py -m timeout -i 5c1612881d --create-project
# ./src/debugger3.py -m timeout -i c83a6af781 --create-project
# ./src/debugger3.py -m timeout -i 93c526c629 --create-project
# ./src/debugger3.py -m timeout -i e03d7dc55c --create-project
# ./src/debugger3.py -m timeout -i 9bfdf36ae8 --create-project
# ./src/debugger3.py -m timeout -i 085a5fa6a3 --create-project
# ./src/debugger3.py -m timeout -i af3454b9b7 --create-project
# ./src/debugger3.py -m timeout -i ea5023bb77 --create-project
# ./src/debugger3.py -m timeout -i 93815c9e8c --create-project
# ./src/debugger3.py -m timeout -i 0e45874c62 --create-project
# ./src/debugger3.py -m timeout -i 52bd8e7cb8 --create-project
# ./src/debugger3.py -m timeout -i bacb951c70 --create-project
# ./src/debugger3.py -m timeout -i b0d1db8445 --create-project
# ./src/debugger3.py -m timeout -i a05a8d0e07 --create-project
# ./src/debugger3.py -m timeout -i e0ef4bae19 --create-project
# ./src/debugger3.py -m timeout -i 4dc3312a9a --create-project
# ./src/debugger3.py -m timeout -i 0b72dcef64 --create-project
# ./src/debugger3.py -m timeout -i 0cedd72fe1 --create-project
# ./src/debugger3.py -m timeout -i a4cb7288c6 --create-project
# ./src/debugger3.py -m timeout -i 4d6ae633c8 --create-project
# ./src/debugger3.py -m timeout -i 82f91d0d6f --create-project
# ./src/debugger3.py -m timeout -i 270b8c3ed1 --create-project
# ./src/debugger3.py -m timeout -i 7373c499e2 --create-project
# ./src/debugger3.py -m timeout -i 298f3245ca --create-project
# ./src/debugger3.py -m timeout -i b6c73c6fb9 --create-project
# ./src/debugger3.py -m timeout -i 44ac0b7ce8 --create-project
# ./src/debugger3.py -m timeout -i 9796f7a39f --create-project
# ./src/debugger3.py -m timeout -i fb2ca1a594 --create-project
# ./src/debugger3.py -m timeout -i d64b61f919 --create-project
# ./src/debugger3.py -m timeout -i 3b176b0694 --create-project
# ./src/debugger3.py -m timeout -i 751af3ffba --create-project
# ./src/debugger3.py -m timeout -i 975f2fa60e --create-project
# ./src/debugger3.py -m timeout -i b6123843b3 --create-project
# ./src/debugger3.py -m timeout -i d90c817672 --create-project
# ./src/debugger3.py -m timeout -i 0711a2f033 --create-project
# ./src/debugger3.py -m timeout -i 09f0c73516 --create-project
# ./src/debugger3.py -m timeout -i c5b6c95d49 --create-project
# ./src/debugger3.py -m timeout -i 65bb77f5f3 --create-project
# ./src/debugger3.py -m timeout -i 3d19b7e2c9 --create-project
# ./src/debugger3.py -m timeout -i 81d60427e7 --create-project
# ./src/debugger3.py -m timeout -i 897da79a5c --create-project
# ./src/debugger3.py -m timeout -i 443cdbaf14 --create-project
# ./src/debugger3.py -m timeout -i f2162eddbb --create-project
# ./src/debugger3.py -m timeout -i 18defa0150 --create-project
# ./src/debugger3.py -m timeout -i a6e96b148b --create-project
# ./src/debugger3.py -m timeout -i 2f6a6b82e9 --create-project
# ./src/debugger3.py -m timeout -i 3ed30b3382 --create-project
# ./src/debugger3.py -m timeout -i 53b94c898b --create-project
# ./src/debugger3.py -m timeout -i 24a1fea1cb --create-project
# ./src/debugger3.py -m timeout -i cb9ff97970 --create-project
# ./src/debugger3.py -m timeout -i 1f3cf5998c --create-project
# ./src/debugger3.py -m timeout -i ec816f99a1 --create-project
# ./src/debugger3.py -m timeout -i cd0ec39156 --create-project
# ./src/debugger3.py -m timeout -i 555312085e --create-project
# ./src/debugger3.py -m timeout -i 355b104f3e --create-project
# ./src/debugger3.py -m timeout -i 05c075acd8 --create-project
# ./src/debugger3.py -m timeout -i 179f62e2d4 --create-project
# ./src/debugger3.py -m timeout -i 695f604e3c --create-project
# ./src/debugger3.py -m timeout -i fae7756eb4 --create-project
# ./src/debugger3.py -m timeout -i b837e52d8b --create-project
# ./src/debugger3.py -m timeout -i fdcfb278f8 --create-project
# ./src/debugger3.py -m timeout -i 947dcf5ca9 --create-project
# ./src/debugger3.py -m timeout -i de19cf9fa2 --create-project
# ./src/debugger3.py -m timeout -i d1535f1776 --create-project
# ./src/debugger3.py -m timeout -i 1b1f6c70ba --create-project
# ./src/debugger3.py -m timeout -i a19f4272bf --create-project
# ./src/debugger3.py -m timeout -i 4399a84f2c --create-project
# ./src/debugger3.py -m timeout -i 2b22e90742 --create-project
# ./src/debugger3.py -m timeout -i 06a10772cf --create-project
# ./src/debugger3.py -m timeout -i 6d5603f1e4 --create-project
# ./src/debugger3.py -m timeout -i a95607b981 --create-project
# ./src/debugger3.py -m timeout -i 7072b00e75 --create-project
# ./src/debugger3.py -m timeout -i c8498ec17a --create-project
# ./src/debugger3.py -m timeout -i 031b71b1cf --create-project
# ./src/debugger3.py -m timeout -i 9adbe2e346 --create-project
# ./src/debugger3.py -m timeout -i 3d6f2d9f7a --create-project
# ./src/debugger3.py -m timeout -i 50b414ceb9 --create-project
# ./src/debugger3.py -m timeout -i cd99d4eccb --create-project
# ./src/debugger3.py -m timeout -i cd6015582a --create-project
# ./src/debugger3.py -m timeout -i ce3b53d3eb --create-project
# ./src/debugger3.py -m timeout -i e743734c96 --create-project
# ./src/debugger3.py -m timeout -i c1a05b62ba --create-project
# ./src/debugger3.py -m timeout -i 62e586cacd --create-project
# ./src/debugger3.py -m timeout -i 2d00faf52c --create-project
# ./src/debugger3.py -m timeout -i 0ad8073737 --create-project
# ./src/debugger3.py -m timeout -i 1a4c83bd83 --create-project
# ./src/debugger3.py -m timeout -i 90880e63b7 --create-project
# ./src/debugger3.py -m timeout -i ba85c910da --create-project
# ./src/debugger3.py -m timeout -i 802c68cc26 --create-project
# ./src/debugger3.py -m timeout -i d75368331e --create-project
# ./src/debugger3.py -m timeout -i 915d51eada --create-project
# ./src/debugger3.py -m timeout -i ee8d1ab295 --create-project
# ./src/debugger3.py -m timeout -i cc5b8bed53 --create-project
# ./src/debugger3.py -m timeout -i 266488af24 --create-project
# ./src/debugger3.py -m timeout -i 47ef270c0c --create-project
# ./src/debugger3.py -m timeout -i 411ef2f9db --create-project
# ./src/debugger3.py -m timeout -i 70b04e001b --create-project
# ./src/debugger3.py -m timeout -i afa9016fd6 --create-project
# ./src/debugger3.py -m timeout -i caf3ffb720 --create-project
# ./src/debugger3.py -m timeout -i a7a2dc0c2d --create-project
# ./src/debugger3.py -m timeout -i 1c986e634b --create-project
# ./src/debugger3.py -m timeout -i 26cc7a44c8 --create-project
# ./src/debugger3.py -m timeout -i 9e33f70e06 --create-project
# ./src/debugger3.py -m timeout -i 0556ae8c88 --create-project
# ./src/debugger3.py -m timeout -i c7dd9386ea --create-project
# ./src/debugger3.py -m timeout -i 0effbdcba4 --create-project
# ./src/debugger3.py -m timeout -i 3366a80004 --create-project
# ./src/debugger3.py -m timeout -i 36a1859f27 --create-project
# ./src/debugger3.py -m timeout -i 28f9cbda22 --create-project
# ./src/debugger3.py -m timeout -i 22188d7780 --create-project
# ./src/debugger3.py -m timeout -i 7dccaece2d --create-project
# ./src/debugger3.py -m timeout -i 44818bcb1f --create-project
# ./src/debugger3.py -m timeout -i 91f1dee2f1 --create-project
# ./src/debugger3.py -m timeout -i a2998ce7e3 --create-project
# ./src/debugger3.py -m timeout -i b52f25923a --create-project
# ./src/debugger3.py -m timeout -i 44a2764cf8 --create-project
# ./src/debugger3.py -m timeout -i 018a6d3a64 --create-project
# ./src/debugger3.py -m timeout -i 94bc3cfd5f --create-project
# ./src/debugger3.py -m timeout -i dc83338098 --create-project
# ./src/debugger3.py -m timeout -i a972e908eb --create-project
# ./src/debugger3.py -m timeout -i a9102fb49c --create-project
# ./src/debugger3.py -m timeout -i 96f127e037 --create-project
# ./src/debugger3.py -m timeout -i cca6928c4f --create-project
# ./src/debugger3.py -m timeout -i b5d367aaf5 --create-project
# ./src/debugger3.py -m timeout -i b1b86518f3 --create-project
# ./src/debugger3.py -m timeout -i c174525f75 --create-project
# ./src/debugger3.py -m timeout -i 6a7bc24676 --create-project
# ./src/debugger3.py -m timeout -i 3fdafd8cf5 --create-project
# ./src/debugger3.py -m timeout -i 868d0bf364 --create-project
# ./src/debugger3.py -m timeout -i 1a397d663b --create-project
# ./src/debugger3.py -m timeout -i b3ec86d7f1 --create-project
# ./src/debugger3.py -m timeout -i df44b4f111 --create-project
# ./src/debugger3.py -m timeout -i ffa588ca99 --create-project
# ./src/debugger3.py -m timeout -i 03df204fcd --create-project
# ./src/debugger3.py -m timeout -i 1482b405bf --create-project
# ./src/debugger3.py -m timeout -i 2298e56311 --create-project
# ./src/debugger3.py -m timeout -i a5dd7919bb --create-project
# ./src/debugger3.py -m timeout -i 68e476ab9f --create-project
# ./src/debugger3.py -m timeout -i 158af610a6 --create-project
# ./src/debugger3.py -m timeout -i 8be7c5ec27 --create-project
# ./src/debugger3.py -m timeout -i fc23d57b68 --create-project
# ./src/debugger3.py -m timeout -i 17904af761 --create-project
# ./src/debugger3.py -m timeout -i 77448147c2 --create-project
# ./src/debugger3.py -m timeout -i c3e7d9e76e --create-project
# ./src/debugger3.py -m timeout -i 6b4aac4136 --create-project
# ./src/debugger3.py -m timeout -i 58d93cd4ed --create-project
# ./src/debugger3.py -m timeout -i fa733ab6d6 --create-project
# ./src/debugger3.py -m timeout -i 13ee923b22 --create-project
# ./src/debugger3.py -m timeout -i 488737f5fe --create-project
# ./src/debugger3.py -m timeout -i 4cce058390 --create-project
# ./src/debugger3.py -m timeout -i 37eddcb7ab --create-project
# ./src/debugger3.py -m timeout -i 175a618390 --create-project
# ./src/debugger3.py -m timeout -i 87abcdd247 --create-project
# ./src/debugger3.py -m timeout -i f4aec3e1dd --create-project
# ./src/debugger3.py -m timeout -i d71eeda4cd --create-project
# ./src/debugger3.py -m timeout -i d0c54edf56 --create-project
# ./src/debugger3.py -m timeout -i f986501402 --create-project
# ./src/debugger3.py -m timeout -i 2d98098a21 --create-project
# ./src/debugger3.py -m timeout -i 519d87022d --create-project
# ./src/debugger3.py -m timeout -i 7492404d65 --create-project
# ./src/debugger3.py -m timeout -i f7f46a3a04 --create-project
# ./src/debugger3.py -m timeout -i 1dbfa93b6f --create-project
# ./src/debugger3.py -m timeout -i 2f80d5bcaa --create-project
# ./src/debugger3.py -m timeout -i c7b10ef871 --create-project
# ./src/debugger3.py -m timeout -i 67d8d6de26 --create-project
# ./src/debugger3.py -m timeout -i 7f39d29669 --create-project
# ./src/debugger3.py -m timeout -i 74e1d044a1 --create-project
# ./src/debugger3.py -m timeout -i b2c059e298 --create-project
# ./src/debugger3.py -m timeout -i f5dc6f777b --create-project
# ./src/debugger3.py -m timeout -i 95fa9421b7 --create-project
# ./src/debugger3.py -m timeout -i f8271123d9 --create-project
# ./src/debugger3.py -m timeout -i 01b00606af --create-project
# ./src/debugger3.py -m timeout -i 2d513d1a0e --create-project
# ./src/debugger3.py -m timeout -i b6f117b674 --create-project
# ./src/debugger3.py -m timeout -i 112938db3c --create-project
# ./src/debugger3.py -m timeout -i b182e2a043 --create-project
# ./src/debugger3.py -m timeout -i 65f41ba519 --create-project
# ./src/debugger3.py -m timeout -i eff0b44ea2 --create-project
# ./src/debugger3.py -m timeout -i be808dd0c3 --create-project
# ./src/debugger3.py -m timeout -i 8909f4c8e6 --create-project
# ./src/debugger3.py -m timeout -i c5633470e3 --create-project
# ./src/debugger3.py -m timeout -i b6a7ecec0e --create-project
# ./src/debugger3.py -m timeout -i c8a3060122 --create-project
# ./src/debugger3.py -m timeout -i 563f5abfa4 --create-project
# ./src/debugger3.py -m timeout -i 54f8f5c8a6 --create-project
# ./src/debugger3.py -m timeout -i 05641d2609 --create-project
# ./src/debugger3.py -m timeout -i 9b9e796545 --create-project
# ./src/debugger3.py -m timeout -i d8cf640f87 --create-project
# ./src/debugger3.py -m timeout -i b100de24e1 --create-project
# ./src/debugger3.py -m timeout -i e2b0591692 --create-project
# ./src/debugger3.py -m timeout -i 1bcd3aa5cb --create-project
# ./src/debugger3.py -m timeout -i 10b27f0984 --create-project
# ./src/debugger3.py -m timeout -i 1b7f64e95b --create-project
# ./src/debugger3.py -m timeout -i 926dcc2129 --create-project
# ./src/debugger3.py -m timeout -i a40c2ef0b3 --create-project
# ./src/debugger3.py -m timeout -i a854e6c8ad --create-project
# ./src/debugger3.py -m timeout -i 9fe662b14c --create-project
# ./src/debugger3.py -m timeout -i 7e4d6827ed --create-project
# ./src/debugger3.py -m timeout -i 49665b0459 --create-project
# ./src/debugger3.py -m timeout -i 7e492ef45f --create-project
# ./src/debugger3.py -m timeout -i 9c17013417 --create-project
# ./src/debugger3.py -m timeout -i a0c42cc37e --create-project
# ./src/debugger3.py -m timeout -i 6200b46f8f --create-project
# ./src/debugger3.py -m timeout -i d96ff98f2e --create-project
# ./src/debugger3.py -m timeout -i ef84a89ec9 --create-project
# ./src/debugger3.py -m timeout -i d01bd917c5 --create-project
# ./src/debugger3.py -m timeout -i ed36496079 --create-project
# ./src/debugger3.py -m timeout -i cb725a5d7b --create-project
# ./src/debugger3.py -m timeout -i 2ead327dad --create-project
# ./src/debugger3.py -m timeout -i 4819fafc3f --create-project
# ./src/debugger3.py -m timeout -i 4d7e86f7da --create-project
# ./src/debugger3.py -m timeout -i b920f021f6 --create-project
# ./src/debugger3.py -m timeout -i d367d79e56 --create-project
# ./src/debugger3.py -m timeout -i 47c0fbf175 --create-project
# ./src/debugger3.py -m timeout -i adb0c59b26 --create-project
# ./src/debugger3.py -m timeout -i 47775b0cf2 --create-project
# ./src/debugger3.py -m timeout -i 543c83b4e6 --create-project
# ./src/debugger3.py -m timeout -i 1c167aafa9 --create-project
# ./src/debugger3.py -m timeout -i 84faa1a2fa --create-project
# ./src/debugger3.py -m timeout -i 676f102c30 --create-project
# ./src/debugger3.py -m timeout -i 5add81d45d --create-project
# ./src/debugger3.py -m timeout -i 87c4d05add --create-project
# ./src/debugger3.py -m timeout -i 6665cb0a02 --create-project
# ./src/debugger3.py -m timeout -i 9415956048 --create-project
# ./src/debugger3.py -m timeout -i 203627efb4 --create-project
# ./src/debugger3.py -m timeout -i 20983514ab --create-project
# ./src/debugger3.py -m timeout -i 81f91a69f2 --create-project
# ./src/debugger3.py -m timeout -i e695dc7eeb --create-project
# ./src/debugger3.py -m timeout -i 1ebe5e3244 --create-project
# ./src/debugger3.py -m timeout -i 2606c5a287 --create-project
# ./src/debugger3.py -m timeout -i 0334fcf203 --create-project
# ./src/debugger3.py -m timeout -i 4eec50bfef --create-project
# ./src/debugger3.py -m timeout -i 6737d567f9 --create-project
# ./src/debugger3.py -m timeout -i d1b83603db --create-project
# ./src/debugger3.py -m timeout -i 790839853f --create-project
# ./src/debugger3.py -m timeout -i b725c343b6 --create-project
# ./src/debugger3.py -m timeout -i ff70c76375 --create-project
# ./src/debugger3.py -m timeout -i a213073776 --create-project
# ./src/debugger3.py -m timeout -i 93c0449639 --create-project
# ./src/debugger3.py -m timeout -i 1afa5361f7 --create-project
# ./src/debugger3.py -m timeout -i 90270fc66a --create-project
# ./src/debugger3.py -m timeout -i 059d8a76e6 --create-project
# ./src/debugger3.py -m timeout -i 1ecf533970 --create-project
# ./src/debugger3.py -m timeout -i 2211f3ba76 --create-project
# ./src/debugger3.py -m timeout -i 92bd652a7c --create-project
# ./src/debugger3.py -m timeout -i 862cb1068a --create-project
# ./src/debugger3.py -m timeout -i 61daeac2cb --create-project
# ./src/debugger3.py -m timeout -i 061f1d0514 --create-project
# ./src/debugger3.py -m timeout -i 74193764bc --create-project
# ./src/debugger3.py -m timeout -i 085408afeb --create-project
# ./src/debugger3.py -m timeout -i 9b55212ceb --create-project
# ./src/debugger3.py -m timeout -i 2489279611 --create-project
# ./src/debugger3.py -m timeout -i 4ddbe507f4 --create-project
# ./src/debugger3.py -m timeout -i d874a82c3a --create-project
# ./src/debugger3.py -m timeout -i 39c8cf4676 --create-project
# ./src/debugger3.py -m timeout -i 2d9d740dd9 --create-project
# ./src/debugger3.py -m timeout -i 0f400a3f00 --create-project
# ./src/debugger3.py -m timeout -i 7f97f9269e --create-project
# ./src/debugger3.py -m timeout -i 7bde492655 --create-project
# ./src/debugger3.py -m timeout -i 0cce886818 --create-project
# ./src/debugger3.py -m timeout -i 786d3d1ed6 --create-project
# ./src/debugger3.py -m timeout -i ffb00a9e92 --create-project
# ./src/debugger3.py -m timeout -i 3c8b9dae45 --create-project
# ./src/debugger3.py -m timeout -i 0a1a6803c7 --create-project
# ./src/debugger3.py -m timeout -i 1ce0be0d98 --create-project
# ./src/debugger3.py -m timeout -i 4c2945c620 --create-project
# ./src/debugger3.py -m timeout -i 58a0fdb9fc --create-project
# ./src/debugger3.py -m timeout -i 12c7d523b1 --create-project
# ./src/debugger3.py -m timeout -i 1752022f42 --create-project
# ./src/debugger3.py -m timeout -i 7c6738ef40 --create-project
# ./src/debugger3.py -m timeout -i ac4102a2e0 --create-project
# ./src/debugger3.py -m timeout -i 58d0af9026 --create-project
# ./src/debugger3.py -m timeout -i fac95e1ef6 --create-project
# ./src/debugger3.py -m timeout -i 3296ed07d9 --create-project
# ./src/debugger3.py -m timeout -i 90e97b47ee --create-project
# ./src/debugger3.py -m timeout -i 8f383c7db0 --create-project
# ./src/debugger3.py -m timeout -i 1870d1afa7 --create-project
# ./src/debugger3.py -m timeout -i 4ce9083b0d --create-project
# ./src/debugger3.py -m timeout -i 66fdaa7389 --create-project
# ./src/debugger3.py -m timeout -i 72a2c42fee --create-project
# ./src/debugger3.py -m timeout -i f92fbc3fec --create-project
# ./src/debugger3.py -m timeout -i 95ece4e2c8 --create-project
# ./src/debugger3.py -m timeout -i 0e3ac592f3 --create-project
# ./src/debugger3.py -m timeout -i 39dea8e27a --create-project
# ./src/debugger3.py -m timeout -i b231954c65 --create-project
# ./src/debugger3.py -m timeout -i f77473cf84 --create-project
# ./src/debugger3.py -m timeout -i 5d39862f72 --create-project
# ./src/debugger3.py -m timeout -i 391e1b7ac0 --create-project
# ./src/debugger3.py -m timeout -i f1fdf3be38 --create-project
# ./src/debugger3.py -m timeout -i d29cd9f10a --create-project
# ./src/debugger3.py -m timeout -i f5fa3eaaf7 --create-project
# ./src/debugger3.py -m timeout -i 2ca7beb862 --create-project
# ./src/debugger3.py -m timeout -i 5fbc06f886 --create-project
# ./src/debugger3.py -m timeout -i 75a47c804d --create-project
# ./src/debugger3.py -m timeout -i 9b9277bc39 --create-project
# ./src/debugger3.py -m timeout -i 0b346d0f87 --create-project
# ./src/debugger3.py -m timeout -i ab52dadac1 --create-project
# ./src/debugger3.py -m timeout -i 1fc9b21323 --create-project
# ./src/debugger3.py -m timeout -i 7798796cc9 --create-project
# ./src/debugger3.py -m timeout -i d619135268 --create-project
# ./src/debugger3.py -m timeout -i 557e72f7ae --create-project
# ./src/debugger3.py -m timeout -i b96ad66775 --create-project
# ./src/debugger3.py -m timeout -i 5741fd7355 --create-project
# ./src/debugger3.py -m timeout -i 2072de2763 --create-project
# ./src/debugger3.py -m timeout -i 5dc26045ea --create-project
# ./src/debugger3.py -m timeout -i d6c59c638c --create-project
# ./src/debugger3.py -m timeout -i d8fb40a98b --create-project
# ./src/debugger3.py -m timeout -i d9b4a1a745 --create-project
# ./src/debugger3.py -m timeout -i a0a67d231a --create-project
# ./src/debugger3.py -m timeout -i 45d0bd930b --create-project
# ./src/debugger3.py -m timeout -i 07554b6280 --create-project
# ./src/debugger3.py -m timeout -i 73e0c43c61 --create-project
# ./src/debugger3.py -m timeout -i c9d38b4125 --create-project
# ./src/debugger3.py -m timeout -i a027d8f301 --create-project
# ./src/debugger3.py -m timeout -i 3e5ee53876 --create-project
# ./src/debugger3.py -m timeout -i 93954d4dad --create-project
# ./src/debugger3.py -m timeout -i 068433d26a --create-project
# ./src/debugger3.py -m timeout -i 06de62b08b --create-project
# ./src/debugger3.py -m timeout -i a650f4205b --create-project
# ./src/debugger3.py -m timeout -i d82f76226c --create-project
# ./src/debugger3.py -m timeout -i 61fbd4977f --create-project
# ./src/debugger3.py -m timeout -i 59dd7b549d --create-project
# ./src/debugger3.py -m timeout -i f6db5998ec --create-project
# ./src/debugger3.py -m timeout -i c4b6442111 --create-project
# ./src/debugger3.py -m timeout -i 8cd183cebe --create-project
# ./src/debugger3.py -m timeout -i 158bcfb113 --create-project
# ./src/debugger3.py -m timeout -i 02d1b2ad7e --create-project
# ./src/debugger3.py -m timeout -i d27df8e3bb --create-project

# %%
for q in mv.status[StrainerStatus.NOT_TESTED]:
    print("./src/carve_and_rerun.py", mv[q].strainer.test_dir)
