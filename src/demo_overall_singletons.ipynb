# %%
import sys, os

MARIPOSA_PATH = "/home/yizhou7/mariposa/"

sys.path.append(MARIPOSA_PATH + "src")
os.chdir(MARIPOSA_PATH)

from debugger.tree_node import NodeRef
from evaluator import BenchViewer, Evaluator
from debugger.debugger import Debugger3
from eval_carver import CarverStatus
from benchmark_consts import *
from utils.system_utils import list_smt2_files, get_name_hash
from debugger.mutant_info import TraceFailure
from evaluator import DbgMode

# %%
qs = UNSTABLE_MARIPOSA
# qs = UNSTABLE_VERUS
mv = BenchViewer(qs, DbgMode.SINGLETON)
# for q in qs:
#     print(q)
#     rev = Evaluator(q)
# Out:
# [INFO] [init] dbg root: dbg/2d9d740dd9/ [INFO] [init] dbg root: dbg/059d8a76e6/ [INFO] [init] dbg root: dbg/b1b86518f3/ [INFO] [init] dbg root: dbg/8a59d4481f/ [INFO] [init] dbg root: dbg/630625681a/ [INFO] [init] dbg root: dbg/712b931174/
#
#
# [INFO] [init] dbg root: dbg/09f0c73516/
#
# [INFO] [init] dbg root: dbg/158bcfb113/
#
# [INFO] [init] dbg root: dbg/22d3013ddf/
# [INFO] [init] dbg root: dbg/a70ef5a023/ [INFO] [init] dbg root: dbg/2606c5a287/
# [INFO] [init] dbg root: dbg/d0c54edf56/ [INFO] [init] dbg root: dbg/7f97f9269e/
#
# [WARN] [init] previous debugging attempt has failed, run with --retry-failed if needed!
#
# [WARN] [proof] no proof available
# [INFO] [init] dbg root: dbg/1fc9b21323/ [INFO] [init] dbg root: dbg/1dbfa93b6f/ [INFO] [init] dbg root: dbg/f8e63dc317/ [INFO] [init] dbg root: dbg/4680269ef1/
#
#
#
#
# [INFO] [init] dbg root: dbg/8852397c03/ [INFO] [init] dbg root: dbg/2ead327dad/
#
# [INFO] [init] dbg root: dbg/3ab530aac4/ [INFO] [init] dbg root: dbg/70d34357b4/ [INFO] [init] dbg root: dbg/22bc3230fa/ [INFO] [init] dbg root: dbg/fdcfb278f8/ [INFO] [init] dbg root: dbg/5741fd7355/
#
#
# [INFO] [init] dbg root: dbg/751af3ffba/
#
# [INFO] [init] dbg root: dbg/95fa9421b7/
# [INFO] [init] dbg root: dbg/862cb1068a/
#
# [INFO] [init] dbg root: dbg/ff70c76375/
# [INFO] [init] dbg root: dbg/17b0b45c82/
# [INFO] [init] dbg root: dbg/167389a8ef/
# [INFO] [init] dbg root: dbg/09e4f9c085/ [INFO] [init] dbg root: dbg/9adbe2e346/
#
# [INFO] [init] dbg root: dbg/72d4708532/
# [INFO] [init] dbg root: dbg/47775b0cf2/ [INFO] [init] dbg root: dbg/fa733ab6d6/ [INFO] [init] dbg root: dbg/0c40f30097/ [INFO] [init] dbg root: dbg/085a5fa6a3/ [INFO] [init] dbg root: dbg/67d8d6de26/
#
# [INFO] [init] dbg root: dbg/fae7756eb4/
#
# [INFO] [init] dbg root: dbg/d90c817672/
#
# [INFO] [init] dbg root: dbg/34eda2f999/ [INFO] [init] dbg root: dbg/6a7bc24676/ [INFO] [init] dbg root: dbg/f8271123d9/ [INFO] [init] dbg root: dbg/92bd652a7c/
#
#
#
# [INFO] [init] dbg root: dbg/354809a9f4/
#
# [INFO] [init] dbg root: dbg/93954d4dad/ [INFO] [init] dbg root: dbg/b837e52d8b/ [INFO] [init] dbg root: dbg/cc5b8bed53/
# [INFO] [init] dbg root: dbg/47c0fbf175/
#
#
# [INFO] [init] dbg root: dbg/9c17013417/ [INFO] [init] dbg root: dbg/f986501402/
# [INFO] [init] dbg root: dbg/70b04e001b/
# [INFO] [init] dbg root: dbg/54f8f5c8a6/
# [INFO] [init] dbg root: dbg/416446ca74/
# [INFO] [init] dbg root: dbg/563f5abfa4/
# [INFO] [init] dbg root: dbg/4aecdc3251/
# [INFO] [init] dbg root: dbg/d619135268/
# [INFO] [init] dbg root: dbg/e6d6347750/
# [INFO] [init] dbg root: dbg/82f91d0d6f/
#
# [INFO] [init] dbg root: dbg/068433d26a/ [INFO] [init] dbg root: dbg/47ef270c0c/
#
# [INFO] [init] dbg root: dbg/2ca7beb862/
# [INFO] [init] dbg root: dbg/1b5eabf811/
# [INFO] [init] dbg root: dbg/50e9564b05/ [INFO] [init] dbg root: dbg/3d63ac7eaf/
# [INFO] [init] dbg root: dbg/19e7b4a644/
# [INFO] [init] dbg root: dbg/93815c9e8c/
# [INFO] [init] dbg root: dbg/c8f75a1321/
# [INFO] [init] dbg root: dbg/bfa5905941/
#
# [INFO] [init] dbg root: dbg/81f604e545/ [INFO] [init] dbg root: dbg/d01bd917c5/
# [INFO] [init] dbg root: dbg/3cead21983/
#
# [INFO] [init] dbg root: dbg/d71eeda4cd/
# [INFO] [init] dbg root: dbg/90270fc66a/
# [INFO] [init] dbg root: dbg/52bd8e7cb8/
# [INFO] [init] dbg root: dbg/a40c2ef0b3/
# [INFO] [init] dbg root: dbg/0cedd72fe1/
# [INFO] [init] dbg root: dbg/28b317196a/
# [INFO] [init] dbg root: dbg/897da79a5c/
# [INFO] [init] dbg root: dbg/a0c42cc37e/
# [INFO] [init] dbg root: dbg/a213073776/
# [INFO] [init] dbg root: dbg/1482b405bf/
# [INFO] [init] dbg root: dbg/1c167aafa9/
# [INFO] [init] dbg root: dbg/acf6656f68/
# [INFO] [init] dbg root: dbg/3c8b9dae45/
# [INFO] [init] dbg root: dbg/81df0e63de/
# [INFO] [init] dbg root: dbg/175a618390/
# [INFO] [init] dbg root: dbg/0cfa69df01/
# [INFO] [init] dbg root: dbg/6200b46f8f/
# [INFO] [init] dbg root: dbg/7373c499e2/
# [INFO] [init] dbg root: dbg/543c83b4e6/ [INFO] [init] dbg root: dbg/20983514ab/
#
# [INFO] [init] dbg root: dbg/e3b4e5b780/ [INFO] [init] dbg root: dbg/6fe848cd76/
#
# [INFO] [init] dbg root: dbg/4bb10dc4e9/
# [INFO] [init] dbg root: dbg/9fe662b14c/
# [INFO] [init] dbg root: dbg/c5b6c95d49/
# [INFO] [init] dbg root: dbg/68e476ab9f/
# [INFO] [init] dbg root: dbg/7c6738ef40/
# [INFO] [init] dbg root: dbg/270b8c3ed1/ [INFO] [init] dbg root: dbg/7e4d6827ed/
#
# [INFO] [init] dbg root: dbg/f92fbc3fec/
# [INFO] [init] dbg root: dbg/c8ca6d3f20/ [INFO] [init] dbg root: dbg/d4e5e77cbc/ [INFO] [init] dbg root: dbg/0b346d0f87/
# [INFO] [init] dbg root: dbg/0c00bb9db6/
#
#
# [INFO] [init] dbg root: dbg/28672c8a4e/ [INFO] [init] dbg root: dbg/af3454b9b7/ [INFO] [init] dbg root: dbg/e0ef4bae19/
#
# [INFO] [init] dbg root: dbg/18defa0150/
#
# [INFO] [init] dbg root: dbg/ab52dadac1/ [INFO] [init] dbg root: dbg/b9896cbaf6/ [INFO] [init] dbg root: dbg/45d0bd930b/ [INFO] [init] dbg root: dbg/c9d38b4125/
#
#
#
# [INFO] [init] dbg root: dbg/40d72d4071/ [INFO] [init] dbg root: dbg/01b00606af/ [INFO] [init] dbg root: dbg/2d98098a21/
# [INFO] [init] dbg root: dbg/34ae13040e/
# [INFO] [init] dbg root: dbg/b6f117b674/
#
#
#
# [INFO] [init] dbg root: dbg/041773ee5b/
# [INFO] [init] dbg root: dbg/62e586cacd/ [INFO] [init] dbg root: dbg/3d6f2d9f7a/ [INFO] [init] dbg root: dbg/243ec915e0/ [INFO] [init] dbg root: dbg/05c075acd8/
# [INFO] [init] dbg root: dbg/e9080f3e47/
#
# [INFO] [init] dbg root: dbg/f77473cf84/
# [INFO] [init] dbg root: dbg/c7dd9386ea/
# [INFO] [init] dbg root: dbg/0b497bc090/
# [INFO] [init] dbg root: dbg/018a6d3a64/ [INFO] [init] dbg root: dbg/6b4aac4136/ [INFO] [init] dbg root: dbg/e998d08b31/
#
#
#
# [INFO] [init] dbg root: dbg/a7a2dc0c2d/ [INFO] [init] dbg root: dbg/d8fb40a98b/ [INFO] [init] dbg root: dbg/fc23d57b68/ [INFO] [init] dbg root: dbg/b920f021f6/
#
#
# [INFO] [init] dbg root: dbg/9b9277bc39/ [INFO] [init] dbg root: dbg/5954cb98c8/
#
# [INFO] [init] dbg root: dbg/fa548b2af5/
# [INFO] [init] dbg root: dbg/519d87022d/ [INFO] [init] dbg root: dbg/1b1f6c70ba/
#
#
# [INFO] [init] dbg root: dbg/fb2ca1a594/
# [INFO] [init] dbg root: dbg/ab307c9008/ [INFO] [init] dbg root: dbg/b5cc583f2d/
#
# [INFO] [init] dbg root: dbg/1c986e634b/ [INFO] [init] dbg root: dbg/9b9e796545/
# [INFO] [init] dbg root: dbg/be808dd0c3/ [INFO] [init] dbg root: dbg/b2c059e298/
#
# [INFO] [init] dbg root: dbg/7d2782e41a/ [INFO] [init] dbg root: dbg/443cdbaf14/
#
# [INFO] [init] dbg root: dbg/cc3fad677d/
#
# [INFO] [init] dbg root: dbg/7fd5899ce2/ [INFO] [init] dbg root: dbg/06a10772cf/ [INFO] [init] dbg root: dbg/b52f25923a/
# [INFO] [init] dbg root: dbg/4ddbe507f4/ [INFO] [init] dbg root: dbg/74193764bc/
#
#
# [INFO] [init] dbg root: dbg/11e4bbf583/ [INFO] [init] dbg root: dbg/5e2368e7d9/
#
#
# [INFO] [init] dbg root: dbg/a6e96b148b/
# [INFO] [init] dbg root: dbg/5fbc06f886/
# [INFO] [init] dbg root: dbg/d1535f1776/
# [INFO] [init] dbg root: dbg/44ac0b7ce8/ [INFO] [init] dbg root: dbg/a95607b981/
# [INFO] [init] dbg root: dbg/fa1767e6e3/
#
# [INFO] [init] dbg root: dbg/422a6c0817/
# [INFO] [init] dbg root: dbg/7e3368fab1/
# [INFO] [init] dbg root: dbg/3366a80004/
# [INFO] [init] dbg root: dbg/179f62e2d4/
# [INFO] [init] dbg root: dbg/b96ad66775/
# [INFO] [init] dbg root: dbg/fcb903eff0/ [INFO] [init] dbg root: dbg/2cbf19182c/
#
# [INFO] [init] dbg root: dbg/ef1ebd5d7d/
# [INFO] [init] dbg root: dbg/7bde492655/
# [INFO] [init] dbg root: dbg/ce3b53d3eb/
# [INFO] [init] dbg root: dbg/caebe30494/ [INFO] [init] dbg root: dbg/f9f9100cfb/
#
# [INFO] [init] dbg root: dbg/6f6c55d971/
# [INFO] [init] dbg root: dbg/676f102c30/
# [INFO] [init] dbg root: dbg/48976525b7/
# [INFO] [init] dbg root: dbg/9967bcf803/
# [INFO] [init] dbg root: dbg/4cce058390/
# [INFO] [init] dbg root: dbg/cd0ec39156/ [INFO] [init] dbg root: dbg/14aaa649c7/ [INFO] [init] dbg root: dbg/16f1fdaba7/
#
#
# [WARN] [init] previous debugging attempt has failed, run with --retry-failed if needed!
# [WARN] [proof] no proof available [INFO] [init] dbg root: dbg/a9ba4f3553/
#
# [INFO] [init] dbg root: dbg/e65b46b51f/
# [INFO] [init] dbg root: dbg/d27df8e3bb/
# [INFO] [init] dbg root: dbg/06de62b08b/
# [INFO] [init] dbg root: dbg/1b7f64e95b/
# [INFO] [init] dbg root: dbg/411ef2f9db/
# [INFO] [init] dbg root: dbg/d82f76226c/
# [INFO] [init] dbg root: dbg/d6c59c638c/ [INFO] [init] dbg root: dbg/c97090bb09/
# [INFO] [init] dbg root: dbg/81f91a69f2/
#
# [INFO] [init] dbg root: dbg/8031fd6ec8/
# [INFO] [init] dbg root: dbg/0b72dcef64/
# [INFO] [init] dbg root: dbg/a9102fb49c/ [INFO] [init] dbg root: dbg/7e492ef45f/
#
# [INFO] [init] dbg root: dbg/2f6a6b82e9/
# [INFO] [init] dbg root: dbg/cca6928c4f/
# [INFO] [init] dbg root: dbg/c174525f75/
# [INFO] [init] dbg root: dbg/60095b1a59/ [INFO] [init] dbg root: dbg/ab13d91431/ [INFO] [init] dbg root: dbg/2e7c051a4b/
#
#
# [INFO] [init] dbg root: dbg/8be7c5ec27/
# [INFO] [init] dbg root: dbg/a2998ce7e3/
# [INFO] [init] dbg root: dbg/d29cd9f10a/
# [INFO] [init] dbg root: dbg/b5b0f8c2f2/
# [INFO] [init] dbg root: dbg/c4b6442111/
# [INFO] [init] dbg root: dbg/87c4d05add/ [INFO] [init] dbg root: dbg/3a37e843fb/
#
# [INFO] [init] dbg root: dbg/102194df5e/
# [WARN] [init] previous debugging attempt has failed, run with --retry-failed if needed!
# [WARN] [proof] no proof available
# [INFO] [init] dbg root: dbg/9f41cf9dd5/
# [INFO] [init] dbg root: dbg/37eddcb7ab/
# [INFO] [init] dbg root: dbg/49665b0459/
# [INFO] [init] dbg root: dbg/786d3d1ed6/
# [INFO] [init] dbg root: dbg/c8a3060122/
# [INFO] [init] dbg root: dbg/6bbd2c848c/
# [INFO] [init] dbg root: dbg/c3e7d9e76e/
# [INFO] [init] dbg root: dbg/3b176b0694/ [INFO] [init] dbg root: dbg/868d0bf364/
#
# [INFO] [init] dbg root: dbg/cdfc45fd41/
# [INFO] [init] dbg root: dbg/2d513d1a0e/
# [INFO] [init] dbg root: dbg/30af6a3633/
# [INFO] [init] dbg root: dbg/2b4b7cd571/
# [INFO] [init] dbg root: dbg/842038cbbb/ [INFO] [init] dbg root: dbg/203627efb4/
# [INFO] [init] dbg root: dbg/3ac32afb30/
# [INFO] [init] dbg root: dbg/d75368331e/
#
# [INFO] [init] dbg root: dbg/31258859ac/ [INFO] [init] dbg root: dbg/557e72f7ae/
# [INFO] [init] dbg root: dbg/d87c685738/
# [INFO] [init] dbg root: dbg/ffb00a9e92/
# [INFO] [init] dbg root: dbg/79fffdb8cb/ [INFO] [init] dbg root: dbg/3296ed07d9/
# [INFO] [init] dbg root: dbg/4040d2a20b/
#
# [INFO] [init] dbg root: dbg/50b414ceb9/ [INFO] [init] dbg root: dbg/0f400a3f00/
#
#
# [INFO] [init] dbg root: dbg/dd8e6c2233/
# [INFO] [init] dbg root: dbg/b231954c65/ [INFO] [init] dbg root: dbg/6737d567f9/
#
# [INFO] [init] dbg root: dbg/ec816f99a1/
# [INFO] [init] dbg root: dbg/1f3cf5998c/
# [INFO] [init] dbg root: dbg/02d1b2ad7e/
# [INFO] [init] dbg root: dbg/b6123843b3/ [INFO] [init] dbg root: dbg/e508668090/
# [INFO] [init] dbg root: dbg/d8c158b8bf/
#
# [INFO] [init] dbg root: dbg/4d7e86f7da/
# [INFO] [init] dbg root: dbg/ed36496079/
# [INFO] [init] dbg root: dbg/0334fcf203/ [INFO] [init] dbg root: dbg/1d23e345a5/
# [INFO] [init] dbg root: dbg/dc83338098/
#
# [INFO] [init] dbg root: dbg/11435d7e73/
# [INFO] [init] dbg root: dbg/c83a6af781/
# [INFO] [init] dbg root: dbg/d1b83603db/
# [INFO] [init] dbg root: dbg/462c420128/
# [INFO] [init] dbg root: dbg/84faa1a2fa/
# [INFO] [init] dbg root: dbg/e03d7dc55c/
# [INFO] [init] dbg root: dbg/de19cf9fa2/
# [INFO] [init] dbg root: dbg/2f80d5bcaa/
# [INFO] [init] dbg root: dbg/fdbf242cbe/
# [INFO] [init] dbg root: dbg/b8ed14e0c5/
# [INFO] [init] dbg root: dbg/74e1d044a1/ [INFO] [init] dbg root: dbg/eff0b44ea2/
#
# [INFO] [init] dbg root: dbg/2211f3ba76/
# [INFO] [init] dbg root: dbg/0cce886818/ [INFO] [init] dbg root: dbg/3ed30b3382/
#
# [INFO] [init] dbg root: dbg/a650f4205b/
# [INFO] [init] dbg root: dbg/4ae002e825/
# [INFO] [init] dbg root: dbg/05b5b92f32/
# [INFO] [init] dbg root: dbg/f5dc6f777b/
# [INFO] [init] dbg root: dbg/a0a67d231a/
# [INFO] [init] dbg root: dbg/e466521a27/
# [INFO] [init] dbg root: dbg/de06634d5d/
# [INFO] [init] dbg root: dbg/d9b4a1a745/
# [INFO] [init] dbg root: dbg/1bcd3aa5cb/
# [INFO] [init] dbg root: dbg/65bb77f5f3/
# [INFO] [init] dbg root: dbg/383f10cfb6/ [INFO] [init] dbg root: dbg/926dcc2129/
# [INFO] [init] dbg root: dbg/c066e22df7/
#
# [INFO] [init] dbg root: dbg/297c8f2526/
# [INFO] [init] dbg root: dbg/58a0fdb9fc/
# [INFO] [init] dbg root: dbg/afa9016fd6/ [INFO] [init] dbg root: dbg/9e33f70e06/
#
# [INFO] [init] dbg root: dbg/e05c339447/
# [INFO] [init] dbg root: dbg/1db53f149e/
# [INFO] [init] dbg root: dbg/dea7cbc5c5/ [INFO] [init] dbg root: dbg/a854e6c8ad/
# [INFO] [init] dbg root: dbg/bf6d57d525/
#
# [INFO] [init] dbg root: dbg/bacb951c70/ [INFO] [init] dbg root: dbg/c4350a29e0/
#
# [INFO] [init] dbg root: dbg/ed978bf127/ [INFO] [init] dbg root: dbg/9796f7a39f/
#
# [INFO] [init] dbg root: dbg/73e0c43c61/
# [INFO] [init] dbg root: dbg/1a4c83bd83/
# [INFO] [init] dbg root: dbg/0a1a6803c7/
# [INFO] [init] dbg root: dbg/28f9cbda22/
# [INFO] [init] dbg root: dbg/4eec50bfef/
# [INFO] [init] dbg root: dbg/82035ba9e7/
# [INFO] [init] dbg root: dbg/d367d79e56/
# [INFO] [init] dbg root: dbg/298f3245ca/
# [INFO] [init] dbg root: dbg/5dc26045ea/
# [INFO] [init] dbg root: dbg/d347f45fa2/
# [INFO] [init] dbg root: dbg/95ece4e2c8/ [INFO] [init] dbg root: dbg/2b22e90742/
# [INFO] [init] dbg root: dbg/c48bc62edc/
# [INFO] [init] dbg root: dbg/ba85c910da/
# [INFO] [init] dbg root: dbg/0a4b4299d2/
#
# [INFO] [init] dbg root: dbg/c5633470e3/
# [INFO] [init] dbg root: dbg/cd99d4eccb/
# [INFO] [init] dbg root: dbg/e1c4753770/
# [INFO] [init] dbg root: dbg/17904af761/
# [INFO] [init] dbg root: dbg/b6a7ecec0e/ [INFO] [init] dbg root: dbg/488737f5fe/
#
# [INFO] [init] dbg root: dbg/3e5ee53876/
# [INFO] [init] dbg root: dbg/fb0072addd/
# [INFO] [init] dbg root: dbg/1c02a6059f/
# [INFO] [init] dbg root: dbg/81d60427e7/ [INFO] [init] dbg root: dbg/947dcf5ca9/
#
# [INFO] [init] dbg root: dbg/75a47c804d/ [INFO] [init] dbg root: dbg/caf3ffb720/
#
# [INFO] [init] dbg root: dbg/8e8d83f571/
# [INFO] [init] dbg root: dbg/83c57f0bcb/
# [INFO] [init] dbg root: dbg/1ab6690346/
# [INFO] [init] dbg root: dbg/02378bfc2b/ [INFO] [init] dbg root: dbg/adb0c59b26/ [INFO] [init] dbg root: dbg/d64b61f919/
#
#
# [INFO] [init] dbg root: dbg/df44b4f111/ [INFO] [init] dbg root: dbg/22188d7780/ [INFO] [init] dbg root: dbg/0e45874c62/
#
#
# [INFO] [init] dbg root: dbg/c8498ec17a/
# [INFO] [init] dbg root: dbg/7f39d29669/
# [INFO] [init] dbg root: dbg/4399a84f2c/
# [INFO] [init] dbg root: dbg/1870d1afa7/
# [INFO] [init] dbg root: dbg/f5d478ae5f/
# [INFO] [init] dbg root: dbg/4dc3312a9a/
# [INFO] [init] dbg root: dbg/a4cb7288c6/
# [INFO] [init] dbg root: dbg/667b2b80fe/
# [INFO] [init] dbg root: dbg/031b71b1cf/
# [INFO] [init] dbg root: dbg/802c68cc26/
# [INFO] [init] dbg root: dbg/cc1d9c148f/
# [INFO] [init] dbg root: dbg/355b104f3e/
# [INFO] [init] dbg root: dbg/61daeac2cb/
# [INFO] [init] dbg root: dbg/7798796cc9/
# [INFO] [init] dbg root: dbg/740fdc77a1/
# [INFO] [init] dbg root: dbg/f1fdf3be38/
# [INFO] [init] dbg root: dbg/38d93c5774/
# [INFO] [init] dbg root: dbg/77448147c2/
# [INFO] [init] dbg root: dbg/f6db5998ec/
# [INFO] [init] dbg root: dbg/2d00faf52c/
# [INFO] [init] dbg root: dbg/83448eecf5/
# [INFO] [init] dbg root: dbg/57ff707219/
# [INFO] [init] dbg root: dbg/16e535bb0c/ [INFO] [init] dbg root: dbg/3ed37733c3/
#
# [INFO] [init] dbg root: dbg/91f1dee2f1/
# [INFO] [init] dbg root: dbg/87abcdd247/
# [INFO] [init] dbg root: dbg/5b7d18ab3e/
# [INFO] [init] dbg root: dbg/7b0fbd9a55/
# [INFO] [init] dbg root: dbg/8f383c7db0/
# [INFO] [init] dbg root: dbg/f7f46a3a04/
# [INFO] [init] dbg root: dbg/0defc27a3b/
# [INFO] [init] dbg root: dbg/90e97b47ee/
# [INFO] [init] dbg root: dbg/0effbdcba4/
# [INFO] [init] dbg root: dbg/915d51eada/ [INFO] [init] dbg root: dbg/a027d8f301/
#
# [INFO] [init] dbg root: dbg/790839853f/
# [INFO] [init] dbg root: dbg/93c526c629/
# [INFO] [init] dbg root: dbg/ac4102a2e0/
# [INFO] [init] dbg root: dbg/36a1859f27/
# [INFO] [init] dbg root: dbg/6b83ccf507/
# [INFO] [init] dbg root: dbg/4f68aa20b3/
# [INFO] [init] dbg root: dbg/cd6cdb377d/
# [INFO] [init] dbg root: dbg/7dccaece2d/
# [INFO] [init] dbg root: dbg/cd6015582a/ [INFO] [init] dbg root: dbg/9bfdf36ae8/
#
# [INFO] [init] dbg root: dbg/43588efb1c/
# [INFO] [init] dbg root: dbg/b546a78766/ [INFO] [init] dbg root: dbg/d3b07a4fd8/
#
# [INFO] [init] dbg root: dbg/b778746723/
# [INFO] [init] dbg root: dbg/b100de24e1/
# [INFO] [init] dbg root: dbg/1afa5361f7/
# [INFO] [init] dbg root: dbg/ffa588ca99/
# [INFO] [init] dbg root: dbg/00d9c7f438/
# [INFO] [init] dbg root: dbg/7af5ba0b16/
# [INFO] [init] dbg root: dbg/112938db3c/
# [INFO] [init] dbg root: dbg/13ee923b22/
# [INFO] [init] dbg root: dbg/a88f57c7ea/
# [INFO] [init] dbg root: dbg/519fdc89c1/ [INFO] [init] dbg root: dbg/0416307c14/
#
# [INFO] [init] dbg root: dbg/5d39862f72/
# [INFO] [init] dbg root: dbg/fac95e1ef6/
# [INFO] [init] dbg root: dbg/7fedd43bf6/ [INFO] [init] dbg root: dbg/cbc1128701/
#
# [INFO] [init] dbg root: dbg/613f2c355d/
# [INFO] [init] dbg root: dbg/9415956048/
# [INFO] [init] dbg root: dbg/8cd183cebe/
# [INFO] [init] dbg root: dbg/1996525606/
# [INFO] [init] dbg root: dbg/5af6d28737/
# [INFO] [init] dbg root: dbg/b182e2a043/
# [INFO] [init] dbg root: dbg/395e0108e7/
# [INFO] [init] dbg root: dbg/c1a05b62ba/
# [INFO] [init] dbg root: dbg/3b1c756824/
# [INFO] [init] dbg root: dbg/10b27f0984/
# [INFO] [init] dbg root: dbg/9825043af6/
# [INFO] [init] dbg root: dbg/0897ef84da/
# [INFO] [init] dbg root: dbg/e95adeebaf/
# [INFO] [init] dbg root: dbg/9b55212ceb/
# [INFO] [init] dbg root: dbg/ae3b449b81/
# [INFO] [init] dbg root: dbg/1d32c4d524/
# [INFO] [init] dbg root: dbg/e2b0591692/
# [INFO] [init] dbg root: dbg/a05a8d0e07/
# [INFO] [init] dbg root: dbg/58d93cd4ed/
# [INFO] [init] dbg root: dbg/2298e56311/
# [INFO] [init] dbg root: dbg/4c2945c620/
# [INFO] [init] dbg root: dbg/cb9ff97970/
# [INFO] [init] dbg root: dbg/1752022f42/
# [INFO] [init] dbg root: dbg/1ce0be0d98/
# [INFO] [init] dbg root: dbg/44818bcb1f/
# [INFO] [init] dbg root: dbg/4ce9083b0d/
# [INFO] [init] dbg root: dbg/66fdaa7389/
# [INFO] [init] dbg root: dbg/b3ec86d7f1/
# [INFO] [init] dbg root: dbg/39dea8e27a/
# [INFO] [init] dbg root: dbg/061f1d0514/
# [INFO] [init] dbg root: dbg/2ba7cc6a6a/ [INFO] [init] dbg root: dbg/03df204fcd/
# [INFO] [init] dbg root: dbg/0ad8073737/
# [INFO] [init] dbg root: dbg/f2162eddbb/
# [INFO] [init] dbg root: dbg/a19f4272bf/ [INFO] [init] dbg root: dbg/aa849323ae/
#
# [INFO] [init] dbg root: dbg/8805626a67/
# [INFO] [init] dbg root: dbg/f4aec3e1dd/
# [INFO] [init] dbg root: dbg/e41d0ee45e/
# [INFO] [init] dbg root: dbg/d96ff98f2e/
# [INFO] [init] dbg root: dbg/1a397d663b/
# [INFO] [init] dbg root: dbg/3ec7c6a97c/
# [INFO] [init] dbg root: dbg/80d7543acb/
# [INFO] [init] dbg root: dbg/1ecf533970/
# [INFO] [init] dbg root: dbg/24a1fea1cb/
# [INFO] [init] dbg root: dbg/158af610a6/
# [INFO] [init] dbg root: dbg/58d0af9026/ [INFO] [init] dbg root: dbg/6d5603f1e4/
#
# [INFO] [init] dbg root: dbg/782b28a40e/
# [INFO] [init] dbg root: dbg/e5c19b8ea5/
# [INFO] [init] dbg root: dbg/6884529c21/
# [INFO] [init] dbg root: dbg/72139a143b/
# [INFO] [init] dbg root: dbg/f81ecefbe1/
# [INFO] [init] dbg root: dbg/07554b6280/
# [INFO] [init] dbg root: dbg/1f1391e20c/
# [INFO] [init] dbg root: dbg/39c8cf4676/
# [INFO] [init] dbg root: dbg/96f127e037/
# [INFO] [init] dbg root: dbg/16d92ddc7b/
# [INFO] [init] dbg root: dbg/4d6ae633c8/
# [INFO] [init] dbg root: dbg/94bc3cfd5f/
# [INFO] [init] dbg root: dbg/1f96205287/
# [INFO] [init] dbg root: dbg/d8c62df78c/
# [INFO] [init] dbg root: dbg/adf9eda1ef/
# [INFO] [init] dbg root: dbg/b5d367aaf5/
# [INFO] [init] dbg root: dbg/5ab30afc32/
# [INFO] [init] dbg root: dbg/3fdafd8cf5/
# [INFO] [init] dbg root: dbg/975f2fa60e/
# [INFO] [init] dbg root: dbg/a972e908eb/
# [INFO] [init] dbg root: dbg/555312085e/
# [INFO] [init] dbg root: dbg/d8cf640f87/
# [INFO] [init] dbg root: dbg/1ebe5e3244/
# [INFO] [init] dbg root: dbg/eec60fd21e/
# [INFO] [init] dbg root: dbg/5fbd6f43b7/
# [INFO] [init] dbg root: dbg/7072b00e75/
# [INFO] [init] dbg root: dbg/68aa54b124/
# [INFO] [init] dbg root: dbg/9af86b2cd6/
# [INFO] [init] dbg root: dbg/02ce0894ca/
# [INFO] [init] dbg root: dbg/3ce5c5e4dc/
# [INFO] [init] dbg root: dbg/2a2073ceb5/
# [INFO] [init] dbg root: dbg/9735a6b051/
# [INFO] [init] dbg root: dbg/72a2c42fee/
# [INFO] [init] dbg root: dbg/44a2764cf8/ [INFO] [init] dbg root: dbg/266488af24/
#
# [INFO] [init] dbg root: dbg/c2671f2f38/
# [INFO] [init] dbg root: dbg/de58a38d6c/
# [INFO] [init] dbg root: dbg/ea5023bb77/
# [INFO] [init] dbg root: dbg/b5f812a861/
# [INFO] [init] dbg root: dbg/2072de2763/
# [INFO] [init] dbg root: dbg/61fbd4977f/
# [INFO] [init] dbg root: dbg/7eea650229/
# [INFO] [init] dbg root: dbg/e743734c96/
# [INFO] [init] dbg root: dbg/05641d2609/ [INFO] [init] dbg root: dbg/12c7d523b1/
#
# [INFO] [init] dbg root: dbg/a5dd7919bb/
# [INFO] [init] dbg root: dbg/873cd88973/
# [INFO] [init] dbg root: dbg/b725c343b6/ [INFO] [init] dbg root: dbg/ee8d1ab295/
#
# [INFO] [init] dbg root: dbg/213eb33b34/
# [INFO] [init] dbg root: dbg/31e9d7c601/
# [INFO] [init] dbg root: dbg/59dd7b549d/
# [INFO] [init] dbg root: dbg/0ef92feb14/ [INFO] [init] dbg root: dbg/8909f4c8e6/
#
# [INFO] [init] dbg root: dbg/e93855aadd/
# [INFO] [init] dbg root: dbg/695f604e3c/
# [INFO] [init] dbg root: dbg/d874a82c3a/ [INFO] [init] dbg root: dbg/72ad929f41/
#
# [INFO] [init] dbg root: dbg/f5fa3eaaf7/
# [INFO] [init] dbg root: dbg/2489279611/ [INFO] [init] dbg root: dbg/2a3b1202bd/ [INFO] [init] dbg root: dbg/1673ca97a5/
#
#
# [INFO] [init] dbg root: dbg/1de7054a37/
# [INFO] [init] dbg root: dbg/db5b85130e/
# [INFO] [init] dbg root: dbg/c7b10ef871/ [INFO] [init] dbg root: dbg/1d57b073cc/
#
# [INFO] [init] dbg root: dbg/5c1612881d/
# [INFO] [init] dbg root: dbg/0711a2f033/
# [INFO] [init] dbg root: dbg/3c3d86031e/ [INFO] [init] dbg root: dbg/3818823b0a/
# [INFO] [init] dbg root: dbg/b8265691e7/
#
# [INFO] [init] dbg root: dbg/a878753336/
# [INFO] [init] dbg root: dbg/5add81d45d/ [INFO] [init] dbg root: dbg/7492404d65/
#
# [INFO] [init] dbg root: dbg/6f64b72bc8/
# [INFO] [init] dbg root: dbg/f6fde2cf65/
# [INFO] [init] dbg root: dbg/e695dc7eeb/
# [INFO] [init] dbg root: dbg/f335e72a88/
# [INFO] [init] dbg root: dbg/53b94c898b/
# [INFO] [init] dbg root: dbg/473fa6f229/
# [INFO] [init] dbg root: dbg/ef84a89ec9/ [INFO] [init] dbg root: dbg/2a783d134b/
#
# [INFO] [init] dbg root: dbg/3d19b7e2c9/ [WARN] [init] previous debugging attempt has failed, run with --retry-failed if needed!
#
# [WARN] [proof] no proof available
# [INFO] [init] dbg root: dbg/cb725a5d7b/
# [INFO] [init] dbg root: dbg/6665cb0a02/
# [INFO] [init] dbg root: dbg/391e1b7ac0/
# [INFO] [init] dbg root: dbg/125461812b/
# [INFO] [init] dbg root: dbg/4819fafc3f/
# [INFO] [init] dbg root: dbg/0556ae8c88/
# [INFO] [init] dbg root: dbg/2f7324b043/
# [INFO] [init] dbg root: dbg/d727e16c9e/
# [INFO] [init] dbg root: dbg/738511822f/
# [INFO] [init] dbg root: dbg/2362f78e4b/
# [INFO] [init] dbg root: dbg/b0d1db8445/
# [INFO] [init] dbg root: dbg/26cc7a44c8/
# [INFO] [init] dbg root: dbg/ff4c3e8cab/
# [INFO] [init] dbg root: dbg/b6e82319b9/
# [INFO] [init] dbg root: dbg/085408afeb/
# [INFO] [init] dbg root: dbg/90880e63b7/
# [INFO] [init] dbg root: dbg/b6c73c6fb9/
# [INFO] [init] dbg root: dbg/65f41ba519/
# [INFO] [init] dbg root: dbg/1aa46bd795/
# [INFO] [init] dbg root: dbg/fbd113c34b/
# [INFO] [init] dbg root: dbg/0e3ac592f3/
# [INFO] [init] dbg root: dbg/93c0449639/

# %%
mv.status.print_status()
# Out:
# | category                 |   count | percentage   |
# |--------------------------|---------|--------------|
# | CarverStatus.FINISHED    |     487 | 89.36 %      |
# | CarverStatus.NOT_TESTED  |      45 | 8.26 %       |
# | CarverStatus.NOT_CREATED |       9 | 1.65 %       |
# | CarverStatus.NO_PROOF    |       4 | 0.73 %       |
# | total                    |     545 | 100.00 %     |

# %%
for q in mv.status[CarverStatus.NO_PROOF]:
    print(q)

# %%
for q in mv.status[CarverStatus.NOT_CREATED]:
    print("./src/evaluator.py --create-singleton -i", q)

# %%
for q in mv.status[CarverStatus.NOT_TESTED]:
# for q in mv.status[DebuggerStatus.FILTERED_NOT_RAN]:
    assert len(list_smt2_files(mv[q].carver.test_dir)) != 0
    print("python3 src/carve_and_rerun.py", mv[q].filtered_dir)

# %%
print(len(mv.fixable)/len(mv.status[CarverStatus.FINISHED]))
# Out:
# 0.7905544147843943

# %%
dirs_to_send = []
additional = ""

for q in mv.fixable:
    r = mv[q]
    if r.name_hash in LIKELY_FIXED:
        continue
    r.collect_garbage()
    dirs_to_send += r.get_dirs_to_sync()
    additional += f"\"{r.name_hash}\",\n"

print(additional)

for i, d in enumerate(dirs_to_send):
    if i % 5 == 0:
        print("echo '", (i //5 +1), "/", len(dirs_to_send)//5, "'")
    print("rsync -avz", d, "g2001:/home/yizhou7/mariposa/", "--inplace", "--delete", "--relative")
# Out:
# "95fa9421b7",
# "8031fd6ec8",
# "afa9016fd6",
# "2362f78e4b",
#
# echo ' 1 / 4 '
# rsync -avz dbg/95fa9421b7 g2001:/home/yizhou7/mariposa/ --inplace --delete --relative
# rsync -avz data/projs/singleton_95fa9421b7/base.z3 g2001:/home/yizhou7/mariposa/ --inplace --delete --relative
# rsync -avz data/dbs/singleton_95fa9421b7/base.z3 g2001:/home/yizhou7/mariposa/ --inplace --delete --relative
# rsync -avz data/projs/singleton_95fa9421b7.filtered/base.z3 g2001:/home/yizhou7/mariposa/ --inplace --delete --relative
# rsync -avz data/dbs/singleton_95fa9421b7.filtered/base.z3 g2001:/home/yizhou7/mariposa/ --inplace --delete --relative
# echo ' 2 / 4 '
# rsync -avz dbg/8031fd6ec8 g2001:/home/yizhou7/mariposa/ --inplace --delete --relative
# rsync -avz data/projs/singleton_8031fd6ec8/base.z3 g2001:/home/yizhou7/mariposa/ --inplace --delete --relative
# rsync -avz data/dbs/singleton_8031fd6ec8/base.z3 g2001:/home/yizhou7/mariposa/ --inplace --delete --relative
# rsync -avz data/projs/singleton_8031fd6ec8.filtered/base.z3 g2001:/home/yizhou7/mariposa/ --inplace --delete --relative
# rsync -avz data/dbs/singleton_8031fd6ec8.filtered/base.z3 g2001:/home/yizhou7/mariposa/ --inplace --delete --relative
# echo ' 3 / 4 '
# rsync -avz dbg/afa9016fd6 g2001:/home/yizhou7/mariposa/ --inplace --delete --relative
# rsync -avz data/projs/singleton_afa9016fd6/base.z3 g2001:/home/yizhou7/mariposa/ --inplace --delete --relative
# rsync -avz data/dbs/singleton_afa9016fd6/base.z3 g2001:/home/yizhou7/mariposa/ --inplace --delete --relative
# rsync -avz data/projs/singleton_afa9016fd6.filtered/base.z3 g2001:/home/yizhou7/mariposa/ --inplace --delete --relative
# rsync -avz data/dbs/singleton_afa9016fd6.filtered/base.z3 g2001:/home/yizhou7/mariposa/ --inplace --delete --relative
# echo ' 4 / 4 '
# rsync -avz dbg/2362f78e4b g2001:/home/yizhou7/mariposa/ --inplace --delete --relative
# rsync -avz data/projs/singleton_2362f78e4b/base.z3 g2001:/home/yizhou7/mariposa/ --inplace --delete --relative
# rsync -avz data/dbs/singleton_2362f78e4b/base.z3 g2001:/home/yizhou7/mariposa/ --inplace --delete --relative
# rsync -avz data/projs/singleton_2362f78e4b.filtered/base.z3 g2001:/home/yizhou7/mariposa/ --inplace --delete --relative
# rsync -avz data/dbs/singleton_2362f78e4b.filtered/base.z3 g2001:/home/yizhou7/mariposa/ --inplace --delete --relative

# %%
from eval_carver import CarverStatus
from utils.analysis_utils import Categorizer

f_modes = Categorizer()

for query in mv.unfixable | mv.status[CarverStatus.NOT_TESTED].items | mv.status[CarverStatus.NOT_CREATED].items:
    rev: Evaluator = mv[query]
    mi = rev.get_trace_info()
    reason = mi.get_failed_reason()
    f_modes.add_item(reason, query)

f_modes.finalize()

# %%
f_modes.print_status()
# Out:
# | category                  |   count | percentage   |
# |---------------------------|---------|--------------|
# | TraceFailure.TIMEOUT      |     132 | 84.62 %      |
# | TraceFailure.FAST_UNKNOWN |      21 | 13.46 %      |
# | TraceFailure.SLOW_UNKNOWN |       3 | 1.92 %       |
# | total                     |     156 | 100.00 %     |

# %%
for q in f_modes[TraceFailure.TIMEOUT]:
    print(f'"{mv[q].name_hash}",')

# %%
for q in f_modes[TraceFailure.FAST_UNKNOWN]:
    print(q)
for q in f_modes[TraceFailure.SLOW_UNKNOWN]:
    print(q)
