# %%
import sys, os

sys.path.append("/home/yizhou7/mariposa/src")
os.chdir("/home/yizhou7/mariposa/")

from tqdm import tqdm
from enum import Enum
from collections import Counter

from base.solver import RCode
from debugger.demo_utils import Report
from debugger.debugger import Debugger3
from debugger.mutant_info import TraceFailure
from evaluator import Evaluator, BenchViewer
from utils.analysis_utils import Categorizer, fmt_percent

# %%
revs = BenchViewer({'data/projs/anvil/base.z3/fluent-smt-fluent_controller__fluentbit__proof__liveness__resource_match__lemma_from_after_get_resource_step_to_after_update_resource_step.smt2', 'data/projs/anvil/base.z3/fluent-smt-fluent_controller__fluentbit__proof__helper_invariants__validation.3.smt2', 'data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-multilog__setup_v.5.smt2', 'data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-multilog__inv_v.11.smt2', 'data/projs/vsystemsnew/base.z3/mimalloc-smt-page_organization__PageOrg.69.smt2', 'data/projs/verismo.dedup/base.z3/snp__ghcb__proto_page.141.smt2', 'data/projs/anvil/base.z3/zookeeper-smt-zookeeper_controller__proof__liveness__stateful_set_match.2.smt2', 'data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-log__inv_v.13.smt2', 'data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-multilog__inv_v.16.smt2', 'data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-multilog__inv_v.15.smt2', 'data/projs/verismo.dedup/base.z3/bsp__ap.3.smt2', 'data/projs/verismo.dedup/base.z3/vbox__vbox.4.smt2', 'data/projs/anvil/base.z3/zookeeper-smt-zookeeper_controller__proof__helper_invariants__proof__lemma_eventually_always_no_delete_resource_request_msg_in_flight.smt2', 'data/projs/anvil/base.z3/zookeeper-smt-rabbitmq-smt-rabbitmq_controller__proof__helper_invariants__validation__lemma_always_stateful_set_in_create_request_msg_satisfies_unchangeable.smt2', 'data/projs/splinterdb/base.z3/allocation_layer__LikesBetree_v.18.smt2', 'data/projs/anvil/base.z3/zookeeper-smt-rabbitmq-smt-rabbitmq_controller__proof__liveness__stateful_set_match__lemma_from_after_get_stateful_set_step_to_after_update_stateful_set_step.smt2', 'data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-log__logimpl_v.6.smt2', 'data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-multilog__inv_v.2.smt2', 'data/projs/splinterdb/base.z3/allocation_layer__LikesBetree_v__LikesBetree.3.smt2', 'data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-log__inv_v.2.smt2', 'data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-multilog__inv_v.9.smt2', 'data/projs/verismo.dedup/base.z3/boot__init__e820_init.4.smt2', 'data/projs/anvil/base.z3/zookeeper-smt-rabbitmq-smt-rabbitmq_controller__proof__helper_invariants__proof__lemma_eventually_always_every_resource_create_request_implies_at_after_create_resource_step.smt2', 'data/projs/anvil/base.z3/fluent-smt-fluent_controller__fluentbit__proof__liveness__daemon_set_match__lemma_from_after_get_daemon_set_step_to_after_update_daemon_set_step.smt2', 'data/projs/anvil/base.z3/zookeeper-smt-zookeeper_controller__proof__helper_invariants__validation.3.smt2', 'data/projs/vsystemsnew/base.z3/mimalloc-smt-segment__segment_span_free_coalesce_before.smt2', 'data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-log__layout_v.30.smt2', 'data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-multilog__inv_v.14.smt2', 'data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-multilog__inv_v.13.smt2', 'data/projs/anvil/base.z3/fluent-smt-fluent_controller__fluentbit_config__proof__liveness__resource_match.5.smt2', 'data/projs/anvil/base.z3/zookeeper-smt-rabbitmq-smt-rabbitmq_controller__proof__liveness__resource_match.1.smt2', 'data/projs/vsystemsnew/base.z3/mimalloc-smt-commit_segment.1.smt2', 'data/projs/verismo.dedup/base.z3/snp__cpuid.17.smt2', 'data/projs/anvil/base.z3/fluent-smt-fluent_controller__fluentbit_config__proof__liveness__resource_match.6.smt2', 'data/projs/verismo.dedup/base.z3/vbox__vbox.5.smt2', 'data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-log__inv_v.17.smt2', 'data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-multilog__inv_v.17.smt2', 'data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-multilog__inv_v.7.smt2', 'data/projs/anvil/base.z3/zookeeper-smt-zookeeper_controller__proof__helper_invariants__proof.2.smt2', 'data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-log__inv_v.10.smt2', 'data/projs/anvil/base.z3/zookeeper-smt-rabbitmq-smt-rabbitmq_controller__proof__liveness__stateful_set_match__lemma_stateful_set_state_matches_at_after_update_stateful_set_step.smt2', 'data/projs/vsystemsnew/base.z3/page-table-smt-impl_u__l2_refinement.3.smt2', 'data/projs/vsystemsnew/base.z3/mimalloc-smt-config.35.smt2', 'data/projs/verismo.dedup/base.z3/security__monitor.21.smt2', 'data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-log__inv_v.4.smt2', 'data/projs/verismo.dedup/base.z3/boot__init__e820_init_alloc.1.smt2', 'data/projs/verismo.dedup/base.z3/boot__init__e820_init.2.smt2', 'data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-log__inv_v.12.smt2', 'data/projs/vsystemsnew/base.z3/mimalloc-smt-segment__segment_os_alloc.smt2', 'data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-log__inv_v.5.smt2', 'data/projs/anvil/base.z3/fluent-smt-fluent_controller__fluentbit__proof__helper_invariants__proof.9.smt2', 'data/projs/verismo.dedup/base.z3/pgtable_e__pte.20.smt2', 'data/projs/anvil/base.z3/fluent-smt-fluent_controller__fluentbit_config__proof__liveness__resource_match__lemma_from_after_get_resource_step_to_after_create_resource_step.smt2', 'data/projs/anvil/base.z3/zookeeper-smt-zookeeper_controller__proof__helper_invariants__zookeeper_api__lemma_zk_request_implies_step_helper.smt2', 'data/projs/anvil/base.z3/zookeeper-smt-zookeeper_controller__proof__helper_invariants__proof__lemma_always_no_update_status_request_msg_in_flight_of_except_stateful_set.smt2', 'data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-multilog__start_v.2.smt2', 'data/projs/verismo.dedup/base.z3/pgtable_e__pte.18.smt2', 'data/projs/verismo.dedup/base.z3/allocator__linkedlist.10.smt2', 'data/projs/atmosphere/base.z3/kernel__create_and_share_pages.5.smt2', 'data/projs/anvil/base.z3/zookeeper-smt-rabbitmq-smt-rabbitmq_controller__proof__helper_invariants__proof__lemma_eventually_always_object_in_response_at_after_create_resource_step_is_same_as_etcd.smt2', 'data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-multilog__setup_v.6.smt2', 'data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-log__inv_v.14.smt2', 'data/projs/vsystemsnew/base.z3/mimalloc-smt-segment__span_queue_delete.smt2'})
# Out:
# [WARN] [eval] 82449bd2e8 tested count 112 < registered 338
# [WARN] [eval] 66c9bdf69f tested count 1225 < registered 1612

# %%
f_modes = Categorizer()

for query in revs.fixable:
    rev: Evaluator = revs[query]
    mi = rev.get_trace_info()
    reason = mi.get_failed_reason()
    f_modes.add_item(reason, query)

f_modes.finalize()

# %%
f_modes.print_status()
# Out:
# | category                  |   count | percentage   |
# |---------------------------|---------|--------------|
# | TraceFailure.TIMEOUT      |      35 | 55.56 %      |
# | TraceFailure.FAST_UNKNOWN |      27 | 42.86 %      |
# | TraceFailure.SLOW_UNKNOWN |       1 | 1.59 %       |
# | total                     |      63 | 100.00 %     |

# %%
def fixable_by_erase(r: Report):
    assert len(r.stabilized) != 0
    return "erase" in r.stabilized.action.values

def fixable_by_inst(r: Report):
    assert len(r.stabilized) != 0
    return "inst_keep" in r.stabilized.action.values or "inst_replace" in r.stabilized.action.values

to_fixes = Counter()
uk_fixes = Counter()

for k, rev in revs.items():
    r = rev.build_report()

    fixes = []

    if fixable_by_erase(r):
        fixes.append("erase")
    if fixable_by_inst(r):
        fixes.append("inst")

    if len(fixes) == 2:
        fixes.append("both")

    if k in f_modes[TraceFailure.FAST_UNKNOWN]:
        uk_fixes.update(fixes)
    elif k in f_modes[TraceFailure.TIMEOUT]:
        to_fixes.update(fixes)

to_count = len(f_modes[TraceFailure.TIMEOUT])

print("Timeouts", to_count)
print("fixed by")
for i in sorted(to_fixes, key=lambda x: to_fixes[x], reverse=True):
    print(f"\t{i}:", fmt_percent(to_fixes[i], to_count))

print("")

uk_count = len(f_modes[TraceFailure.FAST_UNKNOWN])
print("Fast Unknowns", uk_count)
print("fixed by")
for i in sorted(uk_fixes, key=lambda x: uk_fixes[x], reverse=True):
    print(f"\t{i}:", fmt_percent(uk_fixes[i], uk_count))
# Out:
# Timeouts 35
# fixed by
# 	inst: 91.43%
# 	erase: 65.71%
# 	both: 57.14%
#
# Fast Unknowns 27
# fixed by
# 	inst: 100.0%
# 	erase: 18.52%
# 	both: 18.52%

# %%
import multiprocessing
from utils.cache_utils import *

def get_best_rank(rev: Evaluator):
    report = rev.build_report()
    mi = rev.get_trace_info()
    g = mi.get_trace_graph()
    ratios = rev.get_trace_graph_ratios()
    scores = dict()

    for qname, ratio in ratios.items():
        scores[qname] = g.aggregate_scores(ratio)

    scores = sorted(scores.items(), key=lambda x: x[1], reverse=True)
    ranked = [x[0] for x in scores]
    best_rank = len(ranked)

    for qname in report.stabilized.qname.values:
        best_rank = min(best_rank, ranked.index(qname) + 1)

    return best_rank

def get_best_ranks(mode: TraceFailure):
    jobs = []

    for query in f_modes[mode]:
        rev = revs[query]
        # print(name_hash)
        ratio_cache = rev.name_hash + ".ratios"

        if not has_cache(ratio_cache):
            print("./src/debugger3.py -i", query, "--build-ratios")
            continue

        jobs.append(rev)

    pool = multiprocessing.Pool(16)
    return pool.map(get_best_rank, jobs)

summaries = dict()

for mode in [TraceFailure.SLOW_UNKNOWN, TraceFailure.NOT_FAIL, TraceFailure.TIMEOUT, TraceFailure.FAST_UNKNOWN]:
    summaries[mode] = get_best_ranks(mode)
# Out:
# [INFO] [graph] found dbg/8d058577cd/graphs/shuffle.16031162538414592248.txt
# [INFO] [stats] found dbg/8d058577cd/stats/shuffle.16031162538414592248.txt
# [INFO] [graph] found dbg/fdfae1157a/graphs/shuffle.4882204877945181955.txt
# [INFO] [stats] found dbg/fdfae1157a/stats/shuffle.4882204877945181955.txt
# [INFO] [graph] found dbg/b834736f4d/graphs/rename.12362528586306987492.txt
# [INFO] [stats] found dbg/b834736f4d/stats/rename.12362528586306987492.txt
# [INFO] [graph] found dbg/199ba4594c/graphs/reseed.6506362136541185908.txt
# [INFO] [stats] found dbg/199ba4594c/stats/reseed.6506362136541185908.txt
# [INFO] [graph] found dbg/7a3bd28b48/graphs/reseed.14297332801369262032.txt
# [INFO] [stats] found dbg/7a3bd28b48/stats/reseed.14297332801369262032.txt
# [INFO] [graph] found dbg/08719204aa/graphs/reseed.325235324506828228.txt
# [INFO] [stats] found dbg/08719204aa/stats/reseed.325235324506828228.txt
# [INFO] [graph] found dbg/fef99080cd/graphs/shuffle.3355901794255631888.txt
# [INFO] [stats] found dbg/fef99080cd/stats/shuffle.3355901794255631888.txt
# [INFO] [graph] found dbg/0918f4a55d/graphs/reseed.18009040895761984794.txt [INFO] [graph] found dbg/b119384805/graphs/reseed.2646657787367492671.txt
# [INFO] [graph] found dbg/4d2d4fbc20/graphs/rename.12461037147283411353.txt [INFO] [stats] found dbg/0918f4a55d/stats/reseed.18009040895761984794.txt
#
#
# [INFO] [stats] found dbg/4d2d4fbc20/stats/rename.12461037147283411353.txt [INFO] [stats] found dbg/b119384805/stats/reseed.2646657787367492671.txt
#
# [INFO] [graph] found dbg/634ab613c3/graphs/shuffle.2969354737312180380.txt
# [INFO] [graph] found dbg/6540edb885/graphs/rename.13836234746097889101.txt [INFO] [stats] found dbg/634ab613c3/stats/shuffle.2969354737312180380.txt
#
# [INFO] [stats] found dbg/6540edb885/stats/rename.13836234746097889101.txt
# [INFO] [graph] found dbg/c726bffe99/graphs/rename.2631641013891346680.txt
# [INFO] [stats] found dbg/c726bffe99/stats/rename.2631641013891346680.txt
# [INFO] [graph] found dbg/eccd7ce2d9/graphs/rename.7278557073235958777.txt [INFO] [graph] found dbg/2faba7bd1f/graphs/rename.8561135289699441601.txt
#
# [INFO] [stats] found dbg/eccd7ce2d9/stats/rename.7278557073235958777.txt [INFO] [stats] found dbg/2faba7bd1f/stats/rename.8561135289699441601.txt
#
# [INFO] [graph] found dbg/81b159a977/graphs/shuffle.13806555427178412518.txt
# [INFO] [stats] found dbg/81b159a977/stats/shuffle.13806555427178412518.txt
# [INFO] [graph] found dbg/aad03b9358/graphs/reseed.14685607622128194302.txt
# [INFO] [stats] found dbg/aad03b9358/stats/reseed.14685607622128194302.txt
# [INFO] [graph] found dbg/a7f5536a00/graphs/reseed.6943587227848217496.txt
# [INFO] [stats] found dbg/a7f5536a00/stats/reseed.6943587227848217496.txt
# [INFO] [graph] found dbg/8c0bbf67d0/graphs/reseed.2926928540658751903.txt
# [INFO] [stats] found dbg/8c0bbf67d0/stats/reseed.2926928540658751903.txt
# [INFO] [graph] found dbg/55b4af82a4/graphs/reseed.2446138819067655487.txt
# [INFO] [stats] found dbg/55b4af82a4/stats/reseed.2446138819067655487.txt [INFO] [graph] found dbg/cf8c015bcb/graphs/reseed.14515881125856259207.txt
#
# [INFO] [stats] found dbg/cf8c015bcb/stats/reseed.14515881125856259207.txt
# [INFO] [graph] found dbg/b475a457a9/graphs/reseed.17215664013271804878.txt
# [INFO] [stats] found dbg/b475a457a9/stats/reseed.17215664013271804878.txt
# [INFO] [graph] found dbg/fa2fdaf6e0/graphs/reseed.978582254624960590.txt
# [INFO] [stats] found dbg/fa2fdaf6e0/stats/reseed.978582254624960590.txt
# [INFO] [graph] found dbg/68ac429152/graphs/shuffle.1899044262579460870.txt
# [INFO] [stats] found dbg/68ac429152/stats/shuffle.1899044262579460870.txt
# [INFO] [graph] found dbg/0a3bc89db1/graphs/reseed.2681355025314892744.txt
# [INFO] [stats] found dbg/0a3bc89db1/stats/reseed.2681355025314892744.txt [INFO] [graph] found dbg/83bd54cd1a/graphs/reseed.2707133698505971685.txt
#
# [INFO] [stats] found dbg/83bd54cd1a/stats/reseed.2707133698505971685.txt
# [INFO] [graph] found dbg/48dbc6d4fa/graphs/reseed.10404193983173560533.txt
# [INFO] [stats] found dbg/48dbc6d4fa/stats/reseed.10404193983173560533.txt
# [INFO] [graph] found dbg/a1b4b3fd4a/graphs/rename.16754898796465586930.txt
# [INFO] [stats] found dbg/a1b4b3fd4a/stats/rename.16754898796465586930.txt
#
# [INFO] [stats] found dbg/106770d98e/stats/reseed.3851331470606154282.txt
# [INFO] [graph] found dbg/106770d98e/graphs/reseed.3851331470606154282.txt [INFO] [graph] found dbg/2556504d15/graphs/shuffle.2985516088065258878.txt
# [INFO] [stats] found dbg/2556504d15/stats/shuffle.2985516088065258878.txt
# [INFO] [graph] found dbg/621abdd996/graphs/reseed.1522886428156592486.txt
# [INFO] [stats] found dbg/621abdd996/stats/reseed.1522886428156592486.txt
# [INFO] [graph] found dbg/66c9bdf69f/graphs/reseed.13957856434642412621.txt
# [INFO] [stats] found dbg/66c9bdf69f/stats/reseed.13957856434642412621.txt
# [INFO] [graph] found dbg/82449bd2e8/graphs/rename.8223263913722026815.txt
# [INFO] [stats] found dbg/82449bd2e8/stats/rename.8223263913722026815.txt
# [INFO] [graph] found dbg/9eaad8947e/graphs/rename.6382520140487459991.txt
# [INFO] [stats] found dbg/9eaad8947e/stats/rename.6382520140487459991.txt
# [INFO] [graph] found dbg/f08610121f/graphs/reseed.17699498497585027666.txt
# [INFO] [stats] found dbg/f08610121f/stats/reseed.17699498497585027666.txt
# [INFO] [graph] found dbg/6937ca47cd/graphs/reseed.16593544487877940751.txt
# [INFO] [stats] found dbg/6937ca47cd/stats/reseed.16593544487877940751.txt
# [INFO] [graph] found dbg/be920877ca/graphs/shuffle.14575692651422062579.txt
# [INFO] [stats] found dbg/be920877ca/stats/shuffle.14575692651422062579.txt
# [INFO] [graph] found dbg/025a074d17/graphs/shuffle.7366767861977757192.txt [INFO] [graph] found dbg/c4ec60f8f9/graphs/shuffle.8091374896670368150.txt
#
#
# [INFO] [stats] found dbg/c4ec60f8f9/stats/shuffle.8091374896670368150.txt [INFO] [stats] found dbg/025a074d17/stats/shuffle.7366767861977757192.txt
# [INFO] [graph] found dbg/e1d2573021/graphs/shuffle.6352221195065630423.txt
#
# [INFO] [stats] found dbg/e1d2573021/stats/shuffle.6352221195065630423.txt [INFO] [graph] found dbg/a896b920ca/graphs/shuffle.3935504091054792581.txt
# [INFO] [stats] found dbg/a896b920ca/stats/shuffle.3935504091054792581.txt
# [INFO] [graph] found dbg/2078a24298/graphs/shuffle.8829542882092737644.txt
# [INFO] [stats] found dbg/2078a24298/stats/shuffle.8829542882092737644.txt
# [INFO] [graph] found dbg/09d24c83cd/graphs/shuffle.5558647200263296762.txt
# [INFO] [stats] found dbg/09d24c83cd/stats/shuffle.5558647200263296762.txt
# [INFO] [graph] found dbg/568e167040/graphs/shuffle.8604970216652981868.txt
# [INFO] [stats] found dbg/568e167040/stats/shuffle.8604970216652981868.txt [INFO] [graph] found dbg/32eaf80bcc/graphs/shuffle.6910780131629932731.txt
# [INFO] [graph] found dbg/126f0f80f3/graphs/shuffle.7693207495078702026.txt
#
# [INFO] [stats] found dbg/32eaf80bcc/stats/shuffle.6910780131629932731.txt [INFO] [stats] found dbg/126f0f80f3/stats/shuffle.7693207495078702026.txt
#
# [INFO] [graph] found dbg/92c260e39d/graphs/shuffle.15241268561291675236.txt
# [INFO] [graph] found dbg/89068d3f38/graphs/shuffle.14572447043468962421.txt [INFO] [stats] found dbg/92c260e39d/stats/shuffle.15241268561291675236.txt
# [INFO] [graph] found dbg/492704d0da/graphs/shuffle.1768421775674796906.txt
# [INFO] [stats] found dbg/89068d3f38/stats/shuffle.14572447043468962421.txt
#
# [INFO] [stats] found dbg/492704d0da/stats/shuffle.1768421775674796906.txt
# [INFO] [graph] found dbg/ed912ce861/graphs/shuffle.6336912347899983229.txt
# [INFO] [graph] found dbg/f6f3f962c0/graphs/shuffle.5345052648385214803.txt [INFO] [stats] found dbg/ed912ce861/stats/shuffle.6336912347899983229.txt
#
# [INFO] [stats] found dbg/f6f3f962c0/stats/shuffle.5345052648385214803.txt [INFO] [graph] found dbg/090a2a7d67/graphs/shuffle.10445631812693282071.txt
#
# [INFO] [stats] found dbg/090a2a7d67/stats/shuffle.10445631812693282071.txt
# [INFO] [graph] found dbg/9a3bc13b2d/graphs/rename.6929589352549753340.txt
# [INFO] [graph] found dbg/af029e0bc2/graphs/shuffle.18377065096165493170.txt [INFO] [stats] found dbg/9a3bc13b2d/stats/rename.6929589352549753340.txt
#
# [INFO] [stats] found dbg/af029e0bc2/stats/shuffle.18377065096165493170.txt
# [INFO] [graph] found dbg/fa9020870d/graphs/shuffle.17192080644200663547.txt
# [INFO] [stats] found dbg/fa9020870d/stats/shuffle.17192080644200663547.txt
# [INFO] [graph] found dbg/3c5c22d4a1/graphs/shuffle.6184657921392492698.txt [INFO] [graph] found dbg/815f69b161/graphs/shuffle.17997689439100610842.txt
#
# [INFO] [stats] found dbg/3c5c22d4a1/stats/shuffle.6184657921392492698.txt [INFO] [stats] found dbg/815f69b161/stats/shuffle.17997689439100610842.txt
# [INFO] [graph] found dbg/2045867a58/graphs/shuffle.1580687978232137444.txt
#
# [INFO] [stats] found dbg/2045867a58/stats/shuffle.1580687978232137444.txt
# [INFO] [graph] found dbg/b689a8d455/graphs/shuffle.9658684377955998061.txt
# [INFO] [stats] found dbg/b689a8d455/stats/shuffle.9658684377955998061.txt
# [INFO] [graph] found dbg/e16c5e8c0b/graphs/shuffle.15919015838397219284.txt
# [INFO] [stats] found dbg/e16c5e8c0b/stats/shuffle.15919015838397219284.txt
# [INFO] [graph] found dbg/5a940edd1b/graphs/shuffle.2189555834201964502.txt
# [INFO] [stats] found dbg/5a940edd1b/stats/shuffle.2189555834201964502.txt
# [INFO] [graph] found dbg/c02ff41a27/graphs/shuffle.4351452066286619603.txt
# [INFO] [stats] found dbg/c02ff41a27/stats/shuffle.4351452066286619603.txt
# [INFO] [graph] found dbg/7d8c4302ab/graphs/shuffle.15513482486857776214.txt
# [INFO] [stats] found dbg/7d8c4302ab/stats/shuffle.15513482486857776214.txt

# %%
import os
os.chdir("/home/amarshah/mariposa/src")
from calculate_average_rank import *
os.chdir("/home/yizhou7/mariposa/")


def get_name_hash(filename):
    import hashlib
    return hashlib.sha256(filename.encode()).hexdigest()[0:10]

print([(f, get_name_hash(f), '\n') for f in f_modes[TraceFailure.FAST_UNKNOWN]])
fast_unknown_files = [get_name_hash(f) for f in f_modes[TraceFailure.FAST_UNKNOWN]]
timeout_files = files = [get_name_hash(f) for f in f_modes[TraceFailure.TIMEOUT]]
slow_unknown_files = files = [get_name_hash(f) for f in f_modes[TraceFailure.SLOW_UNKNOWN]]
not_fail_files = files = [get_name_hash(f) for f in f_modes[TraceFailure.NOT_FAIL]]

print(fast_unknown_files)




kw_parameters = {"ranking_heuristic": "proof_count"}
print(files)
fast_unknown_results = calculate_rankings(kw_parameters, fast_unknown_files)
# Out:
# [('data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-multilog__inv_v.2.smt2', '2078a24298', '\n'), ('data/projs/atmosphere/base.z3/kernel__create_and_share_pages.5.smt2', '9a3bc13b2d', '\n'), ('data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-multilog__inv_v.11.smt2', 'b689a8d455', '\n'), ('data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-multilog__inv_v.7.smt2', 'ed912ce861', '\n'), ('data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-log__inv_v.4.smt2', 'be920877ca', '\n'), ('data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-multilog__inv_v.14.smt2', '090a2a7d67', '\n'), ('data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-log__logimpl_v.6.smt2', 'a896b920ca', '\n'), ('data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-multilog__inv_v.9.smt2', 'c02ff41a27', '\n'), ('data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-multilog__setup_v.5.smt2', '5a940edd1b', '\n'), ('data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-log__inv_v.13.smt2', '7d8c4302ab', '\n'), ('data/projs/splinterdb/base.z3/allocation_layer__LikesBetree_v.18.smt2', '2045867a58', '\n'), ('data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-log__inv_v.2.smt2', '492704d0da', '\n'), ('data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-log__inv_v.17.smt2', '025a074d17', '\n'), ('data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-multilog__inv_v.16.smt2', '32eaf80bcc', '\n'), ('data/projs/vsystemsnew/base.z3/page-table-smt-impl_u__l2_refinement.3.smt2', 'c4ec60f8f9', '\n'), ('data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-log__inv_v.5.smt2', 'e1d2573021', '\n'), ('data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-log__inv_v.14.smt2', '3c5c22d4a1', '\n'), ('data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-log__inv_v.12.smt2', '92c260e39d', '\n'), ('data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-multilog__inv_v.17.smt2', 'af029e0bc2', '\n'), ('data/projs/splinterdb/base.z3/allocation_layer__LikesBetree_v__LikesBetree.3.smt2', '09d24c83cd', '\n'), ('data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-log__layout_v.30.smt2', '126f0f80f3', '\n'), ('data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-multilog__start_v.2.smt2', 'e16c5e8c0b', '\n'), ('data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-multilog__setup_v.6.smt2', '568e167040', '\n'), ('data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-multilog__inv_v.13.smt2', 'fa9020870d', '\n'), ('data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-multilog__inv_v.15.smt2', '89068d3f38', '\n'), ('data/projs/vsystemsnew/base.z3/mimalloc-smt-config.35.smt2', 'f6f3f962c0', '\n'), ('data/projs/vsystemsnew/base.z3/verified-storage-smt-verified-storage-smt-storage-node-log__inv_v.10.smt2', '815f69b161', '\n')]
# ['2078a24298', '9a3bc13b2d', 'b689a8d455', 'ed912ce861', 'be920877ca', '090a2a7d67', 'a896b920ca', 'c02ff41a27', '5a940edd1b', '7d8c4302ab', '2045867a58', '492704d0da', '025a074d17', '32eaf80bcc', 'c4ec60f8f9', 'e1d2573021', '3c5c22d4a1', '92c260e39d', 'af029e0bc2', '09d24c83cd', '126f0f80f3', 'e16c5e8c0b', '568e167040', 'fa9020870d', '89068d3f38', 'f6f3f962c0', '815f69b161']
# []
# cache/2078a24298.report
# Printing stuff because min_rank == 1
#                                                                                                                                      qname  trace_count  proof_count  skolem  rank  position
# 0                                                                                                                    prelude_fuel_defaults          140           53   False    53         1
# 1                                                                                                                    prelude_unbox_box_int          570           44   False    44         2
# 2                                                                                                                         prelude_nat_clip          243           39   False    39         3
# 3                                                                                                                              prelude_add          250           39   False    39         3
# 4                                                                                                                     prelude_has_type_int           34           22   False    22         5
# 5                                                                                              user_vstd__seq__axiom_seq_subrange_index_14          107           18   False    18         6
# 6                                                                                                                              prelude_sub          261           17   False    17         7
# 7                                                                                      internal_vstd__seq__Seq<u8.>_unbox_axiom_definition          247           16   False    16         8
# 8                                                                                                user_vstd__seq__axiom_seq_subrange_len_13          244           16   False    16         8
# 9                                                        internal_lib!pmem.pmemspec_t.impl&__6.no_outstanding_writes_in_range.?_definition          156           14    True    14        10
# 10                                                                                    internal_vstd!seq.Seq.subrange.?_pre_post_definition          118           13   False    13        11
# 11                                                                                 internal_lib!pmem.pmemspec_t.extract_bytes.?_definition          171           12   False    12        12
# 12                                                                                       internal_vstd__seq__Seq<u8.>_box_axiom_definition          221           11   False    11        13
# 13                                                                                                                   prelude_box_unbox_int          167           11   False    11        13
# 14                                                                                                                    prelude_has_type_nat           12           10   False    10        15
# 15                                                           internal_lib!pmem.pmcopy_t.PmCopyHelper.spec_from_bytes.?_pre_post_definition          168            9   False     9        16
# 16                                                                                                                          prelude_eucmod           48            9   False     9        16
# 17   internal_ens__lib!pmem.pmemutil_v.lemma_wherever_no_outstanding_writes_persistent_memory_view_can_only_crash_as_committed._definition          162            9    True     9        16
# 18                                                                             internal_lib!pmem.pmcopy_t.spec_padding_needed.?_definition            9            9   False     9        16
# 19                                                                                 internal_vstd__seq__Seq<u8.>_has_type_always_definition           10            9   False     9        16
# 20                                                                    internal_lib!pmem.pmcopy_t.spec_padding_needed.?_pre_post_definition            9            9   False     9        16
# 21                                                                                                  user_vstd__seq__axiom_seq_ext_equal_10          143            8    True     8        22
# 22                                                                                                                           prelude_u_inv          300            8   False     8        22
# 23                                                    internal_ens__lib!multilog.layout_v.lemma_establish_subrange_equivalence._definition          111            7    True     7        24
# 24                                                                                                                  prelude_box_unbox_uint          164            4   False     4        25
# 25                                                               internal_lib!pmem.pmcopy_t.SpecPmSized.spec_size_of.?_pre_post_definition            5            4   False     4        25
# 26                                                                                                                          prelude_mk_fun           50            3   False     3        27
# 27                                                                           internal_lib!pmem.pmcopy_t.PmCopyHelper.spec_crc.?_definition          114            3   False     3        27
# 28                                                                                       internal_vstd!seq.Seq.index.?_pre_post_definition          311            3   False     3        27
# 29                                                                                                                          mariposa_qid_1           40            2   False     2        30
# 30                                                                 internal_lib!multilog.layout_v.deserialize_region_metadata.?_definition           37            2   False     2        30
# 31                                         internal_lib!multilog.multilogspec_t.AbstractLogState./AbstractLogState/log_accessor_definition            2            2   False     2        30
# 32                                                                         internal_lib!multilog.layout_v.deserialize_log_crc.?_definition           45            2   False     2        30
# 33                                                                    internal_lib!multilog.layout_v.deserialize_log_metadata.?_definition            5            2   False     2        30
# 34                                                                     internal_lib!multilog.layout_v.extract_region_metadata.?_definition           33            2   False     2        30
# 35                                                                                                   user_vstd__seq__axiom_seq_new_index_8           65            2   False     2        30
# 36                                                                                                     user_vstd__seq__axiom_seq_new_len_7            8            2   False     2        30
# 37                                                                          internal_lib!multilog.layout_v.extract_global_crc.?_definition           12            2   False     2        30
# 38                                                                    internal_lib__multilog__layout_v__LogMetadata_unbox_axiom_definition           14            2   False     2        30
# 39                                                                      internal_lib!multilog.layout_v.deserialize_global_crc.?_definition           55            2   False     2        30
# 40                                                                     internal_lib!multilog.layout_v.extract_global_metadata.?_definition           41            2   False     2        30
# 41                                                                             internal_lib!multilog.layout_v.extract_log_crc.?_definition           36            2   False     2        30
# 42                                                                          internal_lib!multilog.layout_v.extract_region_crc.?_definition           44            2   False     2        30
# 43                                                                      internal_lib!multilog.layout_v.deserialize_region_crc.?_definition           45            2   False     2        30
# 44                                                                        internal_lib!multilog.layout_v.extract_log_metadata.?_definition            5            2   False     2        30
# 45                                                                 internal_lib__multilog__layout_v__GlobalMetadata_unbox_axiom_definition           32            2   False     2        30
# 46                                                                 internal_lib!multilog.layout_v.deserialize_global_metadata.?_definition           61            2   False     2        30
# 47                                                                                                          prelude_mod_unsigned_in_bounds           48            2   False     2        30
# 48                                                                                             internal_crate__fun__1_box_axiom_definition           49            2   False     2        30
# 49                                                                                                                          mariposa_qid_2           40            2   False     2        30
# 50                                                                 internal_lib__multilog__layout_v__RegionMetadata_unbox_axiom_definition           47            2   False     2        30
# 51                                                                                                                          mariposa_qid_8           16            2   False     2        30
# 52                                             internal_lib!multilog.layout_v.recover_abstract_log_from_region_given_metadata.?_definition           43            2   False     2        30
# 53                                                                  internal_lib!multilog.inv_v.info_consistent_with_log_area.?_definition           21            2    True     2        30
# 54                                                                                           internal_crate__fun__1_constructor_definition          122            2    True     2        30
# 55                                                 internal_lib!multilog.multilogimpl_v.LogInfo./LogInfo/log_area_len_invariant_definition            1            1   False     1        56
# 56                                                             internal_lib__pmem__pmemspec_t__PersistentMemoryByte_unbox_axiom_definition           59            1   False     1        56
# 57                                                          internal_lib!multilog.multilogimpl_v.LogInfo./LogInfo/head_accessor_definition            1            1   False     1        56
# 58                                                         internal_lib!multilog.layout_v.relative_log_pos_to_log_area_offset.?_definition           21            1   False     1        56
# 59                                                  internal_lib!multilog.layout_v.recover_abstract_log_from_region_given_cdb.?_definition            2            1   False     1        56
# 60                                                                  internal_lib!multilog.inv_v.metadata_consistent_with_info.?_definition            1            1   False     1        56
# 61                                                                                                                   prelude_has_type_uint            3            1   False     1        56
# 62                                                           internal_lib__multilog__multilogspec_t__AbstractLogState_box_axiom_definition           42            1   False     1        56
# 63                                                                        internal_lib!multilog.layout_v.get_log_metadata_pos.?_definition            1            1   False     1        56
# 64                                                         internal_lib!multilog.multilogimpl_v.LogInfo./LogInfo/head_invariant_definition            1            1   False     1        56
# 65                                                                            internal_lib!pmem.pmemspec_t.impl&__6.committed.?_definition            1            1   False     1        56
# 66                                                                                                 internal_crate__fun__2_apply_definition            0            1   False     1        56
# 67                                                                  internal_lib__multilog__multilogimpl_v__LogInfo_unbox_axiom_definition            1            1   False     1        56
# 68                           internal_lib!pmem.pmemspec_t.PersistentMemoryRegionView./PersistentMemoryRegionView/state_accessor_definition            1            1   False     1        56
# 69                                         internal_lib!multilog.multilogimpl_v.LogInfo./LogInfo/head_log_area_offset_invariant_definition            2            1   False     1        56
# 70                                                         internal_lib!multilog.multilogspec_t.impl&__0.drop_pending_appends.?_definition            1            1   False     1        56
# 71                                                                                         internal_vstd!seq.Seq.new.?_pre_post_definition           49            1   False     1        56
# 72                                                   internal_lib!multilog.multilogimpl_v.LogInfo./LogInfo/log_length_invariant_definition            1            1   False     1        56
# 73                                                                                         internal_vstd!seq_lib.impl&__0.map.?_definition            2            1   False     1        56
# 74                                                               internal_lib__pmem__pmemspec_t__PersistentMemoryByte_box_axiom_definition           14            1   False     1        56
# 75                                                                                           internal_crate__fun__2_constructor_definition            2            1    True     1        56
# 76                                                                                             internal_crate__fun__2_box_axiom_definition            1            1   False     1        56
# 77                                                  internal_lib!multilog.multilogimpl_v.LogInfo./LogInfo/log_area_len_accessor_definition            1            1   False     1        56
# 78                                                                         internal_lib!pmem.pmemspec_t.impl&__6.len.?_pre_post_definition            2            1   False     1        56
# 79                                                                         internal_lib!pmem.pmemspec_t.impl&__6.can_crash_as.?_definition           58            1    True     1        56
# 80                                                         internal_lib__pmem__pmemspec_t__PersistentMemoryRegionView_box_axiom_definition            1            1   False     1        56
# 81                                           internal_vstd__seq__Seq<lib!pmem.pmemspec_t.PersistentMemoryByte.>_has_type_always_definition            1            1   False     1        56
# 82                                                                                internal_vstd!seq_lib.impl&__0.map.?_pre_post_definition            1            1   False     1        56
# 83                                                                                                                       prelude_unbox_int          140            1   False     1        56
# 84                                             internal_lib!multilog.inv_v.no_outstanding_writes_to_active_metadata_in_region.?_definition            2            1   False     1        56
# 85                                          internal_lib!multilog.multilogimpl_v.LogInfo./LogInfo/head_log_area_offset_accessor_definition            2            1   False     1        56
# 86                                                                   internal_lib__multilog__layout_v__GlobalMetadata_box_axiom_definition           60            1   False     1        56
# 87                             internal_lib!multilog.layout_v.GlobalMetadata./GlobalMetadata/length_of_region_metadata_accessor_definition           45            1   False     1        56
# 88                                                                                 internal_lib!multilog.layout_v.extract_log.?_definition           41            1   False     1        56
# 89                        internal_lib!pmem.pmemspec_t.PersistentMemoryByte./PersistentMemoryByte/state_at_last_flush_invariant_definition           24            1   False     1        56
# 90                                                   internal_lib__pmem__pmemspec_t__PersistentMemoryRegionView_has_type_always_definition            0            1   False     1        56
# 91                                                    internal_lib!multilog.multilogimpl_v.LogInfo./LogInfo/log_length_accessor_definition            1            1   False     1        56
# 92                                                                                  internal_lib!pmem.pmemspec_t.impl&__6.len.?_definition            2            1   False     1        56
# 93                                                                                                                          prelude_ext_eq          136            1   False     1        56
# 94                                                                                  internal_vstd!seq_lib.impl&__0.drop_first.?_definition          105            0   False     0        95
# 95                                                                                                                  prelude_box_unbox_bool            2            0   False     0        95
# 96                                                                                                                          mariposa_qid_7          126            0   False     0        95
# 97                                                           internal_lib!multilog.layout_v.deserialize_log_metadata.?_pre_post_definition            5            0   False     0        95
# 98                                                       internal_lib!multilog.layout_v.LogMetadata./LogMetadata/head_invariant_definition           18            0   False     0        95
# 99                                          internal_lib!multilog.layout_v.RegionMetadata./RegionMetadata/log_area_len_accessor_definition           40            0   False     0        95
# 100                                                                                                                      __AIR_ARRAY_QID__            1            0   False     0        95
# 101                                    internal_lib!multilog.multilogspec_t.AbstractLogState./AbstractLogState/pending_accessor_definition            2            0   False     0        95
# 102                                                                        internal_lib!pmem.pmemspec_t.spec_crc_u64.?_pre_post_definition           70            0   False     0        95
# 103                                                                                                                 prelude_unbox_box_bool            1            0   False     0        95
# 104                                        internal_lib!multilog.layout_v.recover_abstract_log_from_region_given_cdb.?_pre_post_definition            2            0   False     0        95
# 105                                                                     internal_lib__multilog__layout_v__LogMetadata_box_axiom_definition            7            0   False     0        95
# 106                                                       internal_lib!multilog.layout_v.deserialize_global_metadata.?_pre_post_definition           60            0   False     0        95
# 107                                   internal_lib!multilog.multilogspec_t.AbstractLogState./AbstractLogState/capacity_accessor_definition            1            0   False     0        95
# 108                                                internal_lib!multilog.layout_v.LogMetadata./LogMetadata/log_length_invariant_definition           18            0   False     0        95
# 109                                                                                                user_vstd__array__array_len_matches_n_2            4            0   False     0        95
# 110                                             internal_lib!multilog.layout_v.RegionMetadata./RegionMetadata/num_logs_accessor_definition           41            0   False     0        95
# 111                                                                               internal_vstd__seq__Seq<nat.>_has_type_always_definition            2            0   False     0        95
# 112                                        internal_lib!multilog.layout_v.RegionMetadata./RegionMetadata/log_area_len_invariant_definition           39            0   False     0        95
# 113                                                            internal_lib!multilog.layout_v.deserialize_region_crc.?_pre_post_definition           42            0   False     0        95
# 114                                       internal_lib!multilog.multilogspec_t.AbstractLogState./AbstractLogState/head_accessor_definition            1            0   False     0        95
# 115                                                             internal_lib!pmem.pmcopy_t.SpecPmSized.spec_align_of.?_pre_post_definition            7            0   False     0        95
# 116                                                                                     internal_core__option__Option_box_axiom_definition           41            0   False     0        95
# 117                                                                                   internal_core__option__Option_unbox_axiom_definition           41            0   False     0        95
# 118                                                internal_vstd__seq__Seq<lib!pmem.pmemspec_t.PersistentMemoryByte.>_box_axiom_definition            1            0   False     0        95
# 119                                                                                              internal_vstd!view.View.view.?_definition            4            0   False     0        95
# 120                                                              internal_lib!multilog.layout_v.get_log_metadata_pos.?_pre_post_definition            1            0   False     0        95
# 121                                                                                  internal_lib!util_v.nat_seq_max.?_pre_post_definition            3            0   False     0        95
# 122                                                                                                                  prelude_box_unbox_nat          122            0   False     0        95
# 123                                       internal_lib!multilog.layout_v.GlobalMetadata./GlobalMetadata/version_number_accessor_definition           45            0   False     0        95
# 124                        internal_lib!pmem.pmemspec_t.PersistentMemoryByte./PersistentMemoryByte/state_at_last_flush_accessor_definition           26            0   False     0        95
# 125                                                                                                            prelude_array_index_trigger          127            0   False     0        95
# 126                                                                                                              prelude_type_id_const_int            3            0   False     0        95
# 127                                                       internal_lib!multilog.layout_v.deserialize_region_metadata.?_pre_post_definition           37            0   False     0        95
# 128                                            internal_lib!multilog.layout_v.RegionMetadata./RegionMetadata/which_log_accessor_definition           41            0   False     0        95
# 129                                        internal_lib!multilog.layout_v.GlobalMetadata./GlobalMetadata/program_guid_invariant_definition            1            0   False     0        95
# 130                                                                                           internal_crate__array___box_axiom_definition            3            0   False     0        95
# 131                                          internal_lib!multilog.layout_v.RegionMetadata./RegionMetadata/multilog_id_accessor_definition           41            0   False     0        95
# 132                                                                                     internal_vstd__seq__Seq<nat.>_box_axiom_definition            3            0   False     0        95
# 133                                         internal_lib!multilog.layout_v.GlobalMetadata./GlobalMetadata/program_guid_accessor_definition           45            0   False     0        95
# 134                         internal_lib!pmem.pmemspec_t.PersistentMemoryByte./PersistentMemoryByte/outstanding_write_invariant_definition           56            0   False     0        95
# 135                                                                                      internal_vstd!seq.Seq.empty.?_pre_post_definition            1            0   False     0        95
# 136                                                                 internal_lib!pmem.pmcopy_t.PmCopyHelper.spec_crc.?_pre_post_definition          114            0   False     0        95
# 137                                                 internal_lib!multilog.layout_v.LogMetadata./LogMetadata/log_length_accessor_definition           19            0   False     0        95
# 138                                                                               internal_lib!util_v.nat_seq_max._fuel_to_body_definition            6            0   False     0        95
# 139                                                                                     internal_vstd!view.View.view.?_pre_post_definition            3            0   False     0        95
# 140                                          internal_lib!multilog.layout_v.RegionMetadata./RegionMetadata/region_size_accessor_definition           41            0   False     0        95
# 141                                                                                                                  prelude_has_type_bool            2            0   False     0        95
# 142                                                                                                                      prelude_array_new            3            0   False     0        95
# 143                                                                      internal_proj__vstd!view.View./V_assoc_type_impl_false_definition            4            0   False     0        95
# 144                                                                                internal_vstd__raw_ptr__Metadata_unbox_axiom_definition            1            0   False     0        95
# 145                                                                               internal_lib!util_v.nat_seq_max._fuel_to_zero_definition          111            0   False     0        95
# 146                                                            internal_lib!pmem.pmcopy_t.PmCopyHelper.spec_to_bytes.?_pre_post_definition           70            0   False     0        95
# 147                                                                                                           prelude_has_type_array_index            2            0   False     0        95
# 148                                                                                            internal_vstd!array.array_view.?_definition            6            0   False     0        95
# 149                                                                                  internal_vstd__raw_ptr__Metadata_box_axiom_definition            1            0   False     0        95
# 150                                   internal_lib!multilog.layout_v.recover_abstract_log_from_region_given_metadata.?_pre_post_definition            1            0   False     0        95
# 151                                                                                   internal_vstd__seq__Seq<nat.>_unbox_axiom_definition          109            0   False     0        95
# 152                                                                   internal_lib__multilog__multilogimpl_v__LogInfo_box_axiom_definition            1            0   False     0        95
# 153                                                                                                                     prelude_unbox_uint          108            0   False     0        95
# 154                                     internal_lib!multilog.multilogimpl_v.LogInfo./LogInfo/log_plus_pending_length_invariant_definition            2            0   False     0        95
# 155                           internal_lib!multilog.layout_v.GlobalMetadata./GlobalMetadata/length_of_region_metadata_invariant_definition            3            0   False     0        95
# 156                                                                                        internal_vstd!seq.Seq.len.?_pre_post_definition          241            0   False     0        95
# 157                                                                                                  user_vstd__array__lemma_array_index_1           20            0   False     0        95
# 158                                                                                                             prelude_has_type_array_new            3            0   False     0        95
# 159                          internal_lib!pmem.pmemspec_t.PersistentMemoryByte./PersistentMemoryByte/outstanding_write_accessor_definition           76            0   False     0        95
# 160                                                                                                                    __AIR_ARRAY_QID___1            2            0   False     0        95
# 161                                                                                   internal_vstd!array.array_view.?_pre_post_definition            4            0   False     0        95
# 162                                                       internal_lib!multilog.layout_v.LogMetadata./LogMetadata/head_accessor_definition           19            0   False     0        95
# 163                                      internal_lib!multilog.multilogimpl_v.LogInfo./LogInfo/log_plus_pending_length_accessor_definition            2            0   False     0        95
# 164                                                            internal_lib!multilog.layout_v.deserialize_global_crc.?_pre_post_definition           54            0   False     0        95
# 165                                         internal_lib!multilog.layout_v.RegionMetadata./RegionMetadata/region_size_invariant_definition            3            0   False     0        95
# 166                                                               internal_lib!multilog.layout_v.deserialize_log_crc.?_pre_post_definition           23            0   False     0        95
# 167                                                                  internal_lib__multilog__layout_v__RegionMetadata_box_axiom_definition           35            0   False     0        95
# 168                                      internal_lib!multilog.layout_v.GlobalMetadata./GlobalMetadata/version_number_invariant_definition            1            0   False     0        95
# 169                                                                        internal_vstd!seq_lib.impl&__0.drop_first.?_pre_post_definition          105            0   False     0        95
# 170                                                                                           internal_lib!util_v.nat_seq_max.?_definition            3            0   False     0        95
# The min rank is 3
#                                                          qname        action                                              edit_path
# 0                                             prelude_nat_clip  inst_replace  data/projs/singleton_2078a24298/base.z3/0bbd00e5.smt2
# 1  internal_lib!pmem.pmcopy_t.spec_padding_needed.?_definition     inst_keep  data/projs/singleton_2078a24298/base.z3/4f91bee7.smt2
# 2                                               prelude_eucmod     inst_keep  data/projs/singleton_2078a24298/base.z3/57536093.smt2
# 3                                                  prelude_sub     inst_keep  data/projs/singleton_2078a24298/base.z3/799880e0.smt2
# 4                                             prelude_nat_clip     inst_keep  data/projs/singleton_2078a24298/base.z3/9689b33d.smt2
# 5  internal_lib!pmem.pmcopy_t.spec_padding_needed.?_definition  inst_replace  data/projs/singleton_2078a24298/base.z3/a862c66e.smt2
# 6                                               prelude_eucmod  inst_replace  data/projs/singleton_2078a24298/base.z3/c5a7e09b.smt2
#                                                                                                                                      qname        action   result   time                                              edit_path
# 0                                                  internal_lib!multilog.multilogimpl_v.LogInfo./LogInfo/log_area_len_invariant_definition  inst_replace    unsat  0.206  data/projs/singleton_2078a24298/base.z3/010975dc.smt2
# 1                                                                       internal_lib!multilog.layout_v.deserialize_region_crc.?_definition     inst_keep    unsat  0.230  data/projs/singleton_2078a24298/base.z3/01545674.smt2
# 2                                              internal_lib!multilog.layout_v.RegionMetadata./RegionMetadata/which_log_accessor_definition         erase    unsat  0.200  data/projs/singleton_2078a24298/base.z3/015e0d38.smt2
# 3                                                                                              internal_crate__fun__2_box_axiom_definition  inst_replace    unsat  0.222  data/projs/singleton_2078a24298/base.z3/02d50371.smt2
# 4                                                                                                             prelude_has_type_array_index         erase    unsat  0.198  data/projs/singleton_2078a24298/base.z3/035269b7.smt2
# 5                                                                   internal_lib!multilog.inv_v.metadata_consistent_with_info.?_definition  inst_replace    unsat  0.256  data/projs/singleton_2078a24298/base.z3/05f67aff.smt2
# 6                                                    internal_lib__pmem__pmemspec_t__PersistentMemoryRegionView_has_type_always_definition  inst_replace    unsat  0.184  data/projs/singleton_2078a24298/base.z3/08911cf1.smt2
# 7                                                                                                                            prelude_u_inv  inst_replace    unsat  0.239  data/projs/singleton_2078a24298/base.z3/0ba4f0ec.smt2
# 8                                                                                                                         prelude_nat_clip  inst_replace    unsat  0.248  data/projs/singleton_2078a24298/base.z3/0bbd00e5.smt2
# 9                                                                                  internal_vstd__seq__Seq<u8.>_has_type_always_definition  inst_replace    unsat  0.186  data/projs/singleton_2078a24298/base.z3/0e60375d.smt2
# 10                                                                     internal_lib!multilog.layout_v.extract_region_metadata.?_definition  inst_replace    unsat  0.200  data/projs/singleton_2078a24298/base.z3/0f0b50bd.smt2
# 11                                                 internal_vstd__seq__Seq<lib!pmem.pmemspec_t.PersistentMemoryByte.>_box_axiom_definition         erase    unsat  0.224  data/projs/singleton_2078a24298/base.z3/0fa0e062.smt2
# 12                                          internal_lib!multilog.multilogimpl_v.LogInfo./LogInfo/head_log_area_offset_accessor_definition  inst_replace    unsat  0.215  data/projs/singleton_2078a24298/base.z3/0fb68a92.smt2
# 13                                                                                                                    prelude_has_type_int     inst_keep  unknown  0.148  data/projs/singleton_2078a24298/base.z3/11c97c25.smt2
# 14                                                               internal_lib!pmem.pmcopy_t.SpecPmSized.spec_size_of.?_pre_post_definition     inst_keep    unsat  0.233  data/projs/singleton_2078a24298/base.z3/12786964.smt2
# 15                                                                                                   user_vstd__array__lemma_array_index_1         erase    unsat  0.200  data/projs/singleton_2078a24298/base.z3/1303fa7d.smt2
# 16                                                                          internal_lib!multilog.layout_v.extract_global_crc.?_definition  inst_replace    unsat  0.184  data/projs/singleton_2078a24298/base.z3/1595ce4a.smt2
# 17                                                                                                               prelude_type_id_const_int         erase    unsat  0.230  data/projs/singleton_2078a24298/base.z3/15f57ec4.smt2
# 18                                                  internal_lib!multilog.multilogimpl_v.LogInfo./LogInfo/log_area_len_accessor_definition     inst_keep    unsat  0.223  data/projs/singleton_2078a24298/base.z3/16080f71.smt2
# 19                                                                    internal_lib__multilog__layout_v__LogMetadata_unbox_axiom_definition     inst_keep    unsat  0.150  data/projs/singleton_2078a24298/base.z3/169f86c1.smt2
# 20                                                                         internal_lib!pmem.pmemspec_t.impl&__6.can_crash_as.?_definition     skolemize    unsat  0.228  data/projs/singleton_2078a24298/base.z3/17ba6bc8.smt2
# 21                                       internal_lib!multilog.layout_v.GlobalMetadata./GlobalMetadata/version_number_invariant_definition         erase    unsat  0.230  data/projs/singleton_2078a24298/base.z3/18104611.smt2
# 22                                                                        internal_lib!multilog.layout_v.extract_log_metadata.?_definition  inst_replace    unsat  0.191  data/projs/singleton_2078a24298/base.z3/1907b1d3.smt2
# 23                                                       internal_lib!pmem.pmemspec_t.impl&__6.no_outstanding_writes_in_range.?_definition     skolemize    unsat  0.225  data/projs/singleton_2078a24298/base.z3/1be0b42f.smt2
# 24                                                                 internal_lib!multilog.layout_v.deserialize_global_metadata.?_definition  inst_replace    unsat  0.166  data/projs/singleton_2078a24298/base.z3/1d282a5c.smt2
# 25                                                                                         internal_vstd!seq_lib.impl&__0.map.?_definition     inst_keep    unsat  0.197  data/projs/singleton_2078a24298/base.z3/1d74cc9c.smt2
# 26                                                                    internal_lib!pmem.pmcopy_t.spec_padding_needed.?_pre_post_definition     inst_keep    unsat  0.203  data/projs/singleton_2078a24298/base.z3/1e0dcfd2.smt2
# 27                                                  internal_lib!multilog.multilogimpl_v.LogInfo./LogInfo/log_area_len_accessor_definition  inst_replace    unsat  0.225  data/projs/singleton_2078a24298/base.z3/20069a97.smt2
# 28                                                                                                             prelude_array_index_trigger         erase    unsat  0.196  data/projs/singleton_2078a24298/base.z3/209e04a1.smt2
# 29                                                        internal_lib!multilog.layout_v.LogMetadata./LogMetadata/head_accessor_definition         erase    unsat  0.194  data/projs/singleton_2078a24298/base.z3/20a5966c.smt2
# 30                                         internal_lib!multilog.layout_v.recover_abstract_log_from_region_given_cdb.?_pre_post_definition         erase    unsat  0.195  data/projs/singleton_2078a24298/base.z3/21d13279.smt2
# 31                                                                         internal_lib!multilog.layout_v.deserialize_log_crc.?_definition  inst_replace    unsat  0.217  data/projs/singleton_2078a24298/base.z3/22bd8837.smt2
# 32                                                                  internal_lib__multilog__multilogimpl_v__LogInfo_unbox_axiom_definition  inst_replace    unsat  0.218  data/projs/singleton_2078a24298/base.z3/264118ae.smt2
# 33                                                                      internal_lib__multilog__layout_v__LogMetadata_box_axiom_definition         erase    unsat  0.221  data/projs/singleton_2078a24298/base.z3/276a35ed.smt2
# 34                                                           internal_lib__multilog__multilogspec_t__AbstractLogState_box_axiom_definition     inst_keep    unsat  0.214  data/projs/singleton_2078a24298/base.z3/281f3256.smt2
# 35   internal_ens__lib!pmem.pmemutil_v.lemma_wherever_no_outstanding_writes_persistent_memory_view_can_only_crash_as_committed._definition     skolemize    unsat  0.218  data/projs/singleton_2078a24298/base.z3/28ced257.smt2
# 36                                           internal_vstd__seq__Seq<lib!pmem.pmemspec_t.PersistentMemoryByte.>_has_type_always_definition  inst_replace    unsat  0.201  data/projs/singleton_2078a24298/base.z3/2a353b06.smt2
# 37                                                                                                                          prelude_ext_eq     inst_keep    unsat  0.226  data/projs/singleton_2078a24298/base.z3/2b193335.smt2
# 38                                                          internal_lib!multilog.multilogimpl_v.LogInfo./LogInfo/head_accessor_definition     inst_keep    unsat  0.224  data/projs/singleton_2078a24298/base.z3/2bb39906.smt2
# 39                                                    internal_lib!multilog.multilogimpl_v.LogInfo./LogInfo/log_length_accessor_definition     inst_keep    unsat  0.220  data/projs/singleton_2078a24298/base.z3/2c53580f.smt2
# 40                                                           internal_lib!multilog.layout_v.deserialize_log_metadata.?_pre_post_definition         erase    unsat  0.204  data/projs/singleton_2078a24298/base.z3/2d5ef830.smt2
# 41                                         internal_lib!multilog.multilogimpl_v.LogInfo./LogInfo/head_log_area_offset_invariant_definition  inst_replace    unsat  0.210  data/projs/singleton_2078a24298/base.z3/2d81bb21.smt2
# 42                                                                        internal_lib!multilog.layout_v.get_log_metadata_pos.?_definition  inst_replace    unsat  0.231  data/projs/singleton_2078a24298/base.z3/3086e6aa.smt2
# 43                                                                                                                    prelude_has_type_nat  inst_replace    unsat  0.193  data/projs/singleton_2078a24298/base.z3/310cc5cf.smt2
# 44                                                  internal_lib!multilog.layout_v.LogMetadata./LogMetadata/log_length_accessor_definition         erase    unsat  0.234  data/projs/singleton_2078a24298/base.z3/3184f3c2.smt2
# 45                                                                                 internal_vstd__seq__Seq<u8.>_has_type_always_definition     inst_keep    unsat  0.173  data/projs/singleton_2078a24298/base.z3/33f093c6.smt2
# ...
# 39                                                                     prelude_unbox_int  inst_replace    unsat  0.162  data/projs/singleton_815f69b161/base.z3/53f92302.smt2
# 40                      internal_lib__log__layout_v__RegionMetadata_box_axiom_definition     inst_keep    unsat  0.120  data/projs/singleton_815f69b161/base.z3/553555f0.smt2
# 41                  internal_lib!pmem.pmcopy_t.PmCopyHelper.bytes_parseable.?_definition     inst_keep    unsat  0.182  data/projs/singleton_815f69b161/base.z3/56e9f8c9.smt2
# 42                                                                        prelude_eucmod     inst_keep    unsat  0.138  data/projs/singleton_815f69b161/base.z3/57536093.smt2
# 43                                  internal_vstd!seq.Seq.subrange.?_pre_post_definition  inst_replace    unsat  0.175  data/projs/singleton_815f69b161/base.z3/58a52ee2.smt2
# 44                                                                     __AIR_ARRAY_QID__         erase    unsat  0.148  data/projs/singleton_815f69b161/base.z3/5c9fe574.smt2
# 45                                                                prelude_box_unbox_uint         erase    unsat  0.148  data/projs/singleton_815f69b161/base.z3/5d1fd7a9.smt2
# 46                                           internal_vstd!array.array_view.?_definition         erase    unsat  0.115  data/projs/singleton_815f69b161/base.z3/5f6e4a64.smt2
# 47                                             internal_vstd!view.View.view.?_definition         erase    unsat  0.126  data/projs/singleton_815f69b161/base.z3/5fbc9741.smt2
# 48                                                                    prelude_unbox_uint         erase    unsat  0.147  data/projs/singleton_815f69b161/base.z3/62b0d156.smt2
# 49                                                   user_vstd__seq__axiom_seq_new_len_7         erase    unsat  0.140  data/projs/singleton_815f69b161/base.z3/639432eb.smt2
# 50                                  internal_vstd!array.array_view.?_pre_post_definition         erase    unsat  0.136  data/projs/singleton_815f69b161/base.z3/63f665e6.smt2
# 51                               internal_core!option.Option./Some/0_accessor_definition  inst_replace    unsat  0.148  data/projs/singleton_815f69b161/base.z3/650fd013.smt2
# 52                                                                         prelude_u_inv     inst_keep    unsat  0.148  data/projs/singleton_815f69b161/base.z3/6babc434.smt2
# 53             internal_lib!pmem.pmcopy_t.SpecPmSized.spec_size_of.?_pre_post_definition  inst_replace    unsat  0.137  data/projs/singleton_815f69b161/base.z3/6c7d716e.smt2
# 54                                 internal_vstd__raw_ptr__Metadata_box_axiom_definition         erase    unsat  0.148  data/projs/singleton_815f69b161/base.z3/72536f3c.smt2
# 55                   internal_lib!log.layout_v.deserialize_log_cdb.?_pre_post_definition         erase    unsat  0.144  data/projs/singleton_815f69b161/base.z3/72a2b9f4.smt2
# 56            internal_lib!pmem.pmcopy_t.SpecPmSized.spec_align_of.?_pre_post_definition         erase    unsat  0.159  data/projs/singleton_815f69b161/base.z3/73eab46a.smt2
# 57                                                                           prelude_sub     inst_keep    unsat  0.141  data/projs/singleton_815f69b161/base.z3/799880e0.smt2
# 58                                                                 prelude_fuel_defaults     inst_keep    unsat  0.163  data/projs/singleton_815f69b161/base.z3/7b5d3d82.smt2
# 59                                   internal_vstd__seq__Seq<u8.>_unbox_axiom_definition     inst_keep    unsat  0.154  data/projs/singleton_815f69b161/base.z3/7dd3ef82.smt2
# 60                                                                 prelude_unbox_box_int     inst_keep  unknown  0.087  data/projs/singleton_815f69b161/base.z3/7e1bcc27.smt2
# 61                                   internal_vstd__seq__Seq<u8.>_unbox_axiom_definition  inst_replace    unsat  0.158  data/projs/singleton_815f69b161/base.z3/82ffdc07.smt2
# 62                                internal_lib!log.inv_v.metadata_types_set.?_definition  inst_replace    unsat  0.135  data/projs/singleton_815f69b161/base.z3/863b5708.smt2
# 63                                          internal_crate__array___box_axiom_definition         erase    unsat  0.142  data/projs/singleton_815f69b161/base.z3/883206a4.smt2
# 64                              internal_lib!util_v.nat_seq_max._fuel_to_body_definition         erase    unsat  0.152  data/projs/singleton_815f69b161/base.z3/8a40828c.smt2
# 65                                                                 prelude_fuel_defaults  inst_replace    unsat  0.139  data/projs/singleton_815f69b161/base.z3/8ab12f96.smt2
# 66                                                 user_vstd__seq__axiom_seq_new_index_8         erase    unsat  0.138  data/projs/singleton_815f69b161/base.z3/917cef74.smt2
# 67                                                                        prelude_mk_fun         erase    unsat  0.143  data/projs/singleton_815f69b161/base.z3/92e51f02.smt2
# 68                    internal_lib__log__layout_v__RegionMetadata_unbox_axiom_definition  inst_replace    unsat  0.138  data/projs/singleton_815f69b161/base.z3/93f21d79.smt2
# 69                                                                      prelude_nat_clip     inst_keep    unsat  0.110  data/projs/singleton_815f69b161/base.z3/9689b33d.smt2
# 70                       internal_lib!pmem.pmemspec_t.spec_crc_u64.?_pre_post_definition         erase    unsat  0.143  data/projs/singleton_815f69b161/base.z3/9b25a9dc.smt2
# 71                                                                 prelude_box_unbox_nat  inst_replace    unsat  0.136  data/projs/singleton_815f69b161/base.z3/9e51af92.smt2
# 72                                                                        prelude_ext_eq  inst_replace    unsat  0.167  data/projs/singleton_815f69b161/base.z3/a5ddee21.smt2
# 73                               internal_vstd__raw_ptr__Metadata_unbox_axiom_definition         erase    unsat  0.147  data/projs/singleton_815f69b161/base.z3/a742bbb5.smt2
# 74                           internal_lib!pmem.pmcopy_t.spec_padding_needed.?_definition  inst_replace    unsat  0.242  data/projs/singleton_815f69b161/base.z3/a862c66e.smt2
# 75         internal_lib!pmem.pmcopy_t.PmCopyHelper.bytes_parseable.?_pre_post_definition         erase    unsat  0.151  data/projs/singleton_815f69b161/base.z3/a92915be.smt2
# 76                         internal_lib__log__layout_v__LogMetadata_box_axiom_definition  inst_replace    unsat  0.122  data/projs/singleton_815f69b161/base.z3/ab8a3376.smt2
# 77                                         internal_crate__fun__1_constructor_definition         erase    unsat  0.142  data/projs/singleton_815f69b161/base.z3/ad76bc13.smt2
# 78           internal_lib!pmem.pmcopy_t.PmCopyHelper.spec_to_bytes.?_pre_post_definition         erase    unsat  0.255  data/projs/singleton_815f69b161/base.z3/adeacd57.smt2
# 79                                          internal_lib!util_v.nat_seq_max.?_definition         erase    unsat  0.118  data/projs/singleton_815f69b161/base.z3/aec739c3.smt2
# 80                       internal_lib__log__layout_v__LogMetadata_unbox_axiom_definition  inst_replace    unsat  0.162  data/projs/singleton_815f69b161/base.z3/af28170a.smt2
# 81                       internal_vstd!seq_lib.impl&__0.drop_first.?_pre_post_definition         erase    unsat  0.129  data/projs/singleton_815f69b161/base.z3/af4c9405.smt2
# 82                      internal_lib__log__layout_v__GlobalMetadata_box_axiom_definition  inst_replace    unsat  0.130  data/projs/singleton_815f69b161/base.z3/b0612543.smt2
# 83                                                                        mariposa_qid_5         erase    unsat  0.152  data/projs/singleton_815f69b161/base.z3/b10423f9.smt2
# 84                           internal_lib!log.layout_v.get_log_metadata_pos.?_definition     inst_keep    unsat  0.143  data/projs/singleton_815f69b161/base.z3/b50a0a2a.smt2
# 85                                                                           prelude_add     inst_keep  unknown  0.079  data/projs/singleton_815f69b161/base.z3/b64ee6ef.smt2
# 86                         internal_lib__log__layout_v__LogMetadata_box_axiom_definition     inst_keep    unsat  0.123  data/projs/singleton_815f69b161/base.z3/b659b98e.smt2
# 87                    internal_lib__log__layout_v__GlobalMetadata_unbox_axiom_definition     inst_keep    unsat  0.151  data/projs/singleton_815f69b161/base.z3/b66ac966.smt2
# 88                                    internal_core__option__Option_box_axiom_definition  inst_replace    unsat  0.147  data/projs/singleton_815f69b161/base.z3/b6c8e4c4.smt2
# 89                                               user_vstd__array__array_len_matches_n_2         erase    unsat  0.146  data/projs/singleton_815f69b161/base.z3/b845fad7.smt2
# 90                                                                prelude_box_unbox_bool     inst_keep    unsat  0.133  data/projs/singleton_815f69b161/base.z3/b94033c2.smt2
# 91                                                        prelude_mod_unsigned_in_bounds     inst_keep    unsat  0.195  data/projs/singleton_815f69b161/base.z3/b9aa3ae9.smt2
# 92                                internal_vstd!seq_lib.impl&__0.drop_first.?_definition         erase    unsat  0.140  data/projs/singleton_815f69b161/base.z3/ba608f7a.smt2
# 93                                                                prelude_unbox_box_bool  inst_replace    unsat  0.128  data/projs/singleton_815f69b161/base.z3/bbfbdc60.smt2
# 94                              internal_vstd__seq__Seq<nat.>_has_type_always_definition         erase    unsat  0.129  data/projs/singleton_815f69b161/base.z3/bc39347d.smt2
# 95                              internal_lib!util_v.nat_seq_max._fuel_to_zero_definition         erase    unsat  0.148  data/projs/singleton_815f69b161/base.z3/bf0d2db1.smt2
# 96       internal_lib!log.layout_v.RegionMetadata./RegionMetadata_constructor_definition         erase    unsat  0.146  data/projs/singleton_815f69b161/base.z3/c2fe3949.smt2
# 97                                                                     prelude_array_new         erase    unsat  0.147  data/projs/singleton_815f69b161/base.z3/c3110f55.smt2
# 98         internal_lib!log.layout_v.deserialize_and_check_log_cdb.?_pre_post_definition     inst_keep    unsat  0.146  data/projs/singleton_815f69b161/base.z3/c37a518f.smt2
# 99                                                                        prelude_eucmod  inst_replace    unsat  0.144  data/projs/singleton_815f69b161/base.z3/c5a7e09b.smt2
# 100        internal_lib!pmem.pmcopy_t.PmCopyHelper.spec_from_bytes.?_pre_post_definition  inst_replace    unsat  0.149  data/projs/singleton_815f69b161/base.z3/c67b2c18.smt2
# 101                              internal_lib!pmem.pmemspec_t.extract_bytes.?_definition  inst_replace  unknown  0.134  data/projs/singleton_815f69b161/base.z3/c7740b0e.smt2
# 102      internal_ens__lib!log.layout_v.lemma_establish_subrange_equivalence._definition     skolemize    unsat  0.117  data/projs/singleton_815f69b161/base.z3/c7afcf5b.smt2
# 103                    internal_proj__vstd!view.View./V_assoc_type_impl_false_definition         erase    unsat  0.146  data/projs/singleton_815f69b161/base.z3/c7c0026b.smt2
# 104                                internal_lib!util_v.nat_seq_max.?_pre_post_definition         erase    unsat  0.139  data/projs/singleton_815f69b161/base.z3/ce56793e.smt2
# 105                                    internal_vstd__seq__Seq<u8.>_box_axiom_definition  inst_replace    unsat  0.187  data/projs/singleton_815f69b161/base.z3/cecaf79a.smt2
# 106                                    internal_vstd!seq.Seq.index.?_pre_post_definition         erase    unsat  0.140  data/projs/singleton_815f69b161/base.z3/cf72063d.smt2
# 107                                               user_vstd__seq__axiom_seq_ext_equal_10     skolemize    unsat  0.122  data/projs/singleton_815f69b161/base.z3/d31805f8.smt2
# 108                 internal_lib!pmem.pmcopy_t.PmCopyHelper.bytes_parseable.?_definition  inst_replace    unsat  0.178  data/projs/singleton_815f69b161/base.z3/d4a1ba8d.smt2
# 109  internal_ens__lib!log.inv_v.lemma_auto_smaller_range_of_seq_is_subrange._definition     skolemize    unsat  0.149  data/projs/singleton_815f69b161/base.z3/d52819f8.smt2
# 110                           internal_lib!log.layout_v.deserialize_log_cdb.?_definition     inst_keep    unsat  0.136  data/projs/singleton_815f69b161/base.z3/d8adffcb.smt2
# 111                                   internal_vstd!view.View.view.?_pre_post_definition         erase    unsat  0.149  data/projs/singleton_815f69b161/base.z3/d90c5b24.smt2
# 112                                                       prelude_mod_unsigned_in_bounds  inst_replace    unsat  0.151  data/projs/singleton_815f69b161/base.z3/d973fd33.smt2
# 113                                      internal_vstd!seq.Seq.new.?_pre_post_definition         erase    unsat  0.139  data/projs/singleton_815f69b161/base.z3/d9fd888e.smt2
# 114                                                                    prelude_unbox_int     inst_keep    unsat  0.144  data/projs/singleton_815f69b161/base.z3/da1fb964.smt2
# 115                                      internal_vstd!seq.Seq.len.?_pre_post_definition         erase    unsat  0.203  data/projs/singleton_815f69b161/base.z3/dbcfaf7a.smt2
# 116                                 internal_vstd!seq.Seq.subrange.?_pre_post_definition     inst_keep    unsat  0.181  data/projs/singleton_815f69b161/base.z3/e03705b7.smt2
# 117                               internal_lib!log.layout_v.extract_log_cdb.?_definition  inst_replace    unsat  0.131  data/projs/singleton_815f69b161/base.z3/e0a6daf0.smt2
# 118                      internal_lib__log__layout_v__LogMetadata_unbox_axiom_definition     inst_keep    unsat  0.163  data/projs/singleton_815f69b161/base.z3/e1eab141.smt2
# 119                               internal_lib!log.layout_v.extract_log_cdb.?_definition     inst_keep    unsat  0.170  data/projs/singleton_815f69b161/base.z3/e38e065f.smt2
# 120                 internal_lib!log.layout_v.deserialize_and_check_log_cdb.?_definition     inst_keep    unsat  0.201  data/projs/singleton_815f69b161/base.z3/e4a24db8.smt2
# 121        internal_lib!pmem.pmcopy_t.PmCopyHelper.spec_from_bytes.?_pre_post_definition     inst_keep    unsat  0.140  data/projs/singleton_815f69b161/base.z3/e532e570.smt2
# 122                               internal_lib!log.inv_v.metadata_types_set.?_definition     inst_keep    unsat  0.138  data/projs/singleton_815f69b161/base.z3/e6ef8c46.smt2
# 123                 internal_lib!pmem.pmcopy_t.spec_padding_needed.?_pre_post_definition  inst_replace    unsat  0.184  data/projs/singleton_815f69b161/base.z3/ea58c26d.smt2
# 124                                                                 prelude_has_type_nat     inst_keep    unsat  0.190  data/projs/singleton_815f69b161/base.z3/ef540709.smt2
# 125                                            user_vstd__seq__axiom_seq_subrange_len_13  inst_replace    unsat  0.181  data/projs/singleton_815f69b161/base.z3/f0c4f95c.smt2
# 126                  internal_lib!log.inv_v.active_metadata_bytes_are_equal.?_definition     inst_keep    unsat  0.120  data/projs/singleton_815f69b161/base.z3/f2d11a47.smt2
# 127                 internal_lib!log.layout_v.deserialize_and_check_log_cdb.?_definition  inst_replace    unsat  0.128  data/projs/singleton_815f69b161/base.z3/fb610ca3.smt2
# 128                                    internal_vstd__seq__Seq<u8.>_box_axiom_definition     inst_keep    unsat  0.168  data/projs/singleton_815f69b161/base.z3/fef20a5a.smt2
# [3, 8, 4, 2, 35, 31, 20, 1, 9, 43, 4, 8, 6, 5, 9, 6, 14, 19, 3, 3, 7, 5, 9, 7, 5, 2, 4]
# Total:  27  files
# Mean:  10
# Median:  6
# 1 would fix on first try
# 6 would fix in 3 or fewer tries
# 21 would fix in 10 or fewer tries

# %%
slow_unknown_files = files = [get_name_hash(f) for f in f_modes[TraceFailure.SLOW_UNKNOWN]]

kw_parameters = {"ranking_heuristic": "proof_count"}
slow_unknown_results = calculate_rankings(kw_parameters, slow_unknown_files)
# Out:
# cache/8d058577cd.report
# [44]
# Total:  1  files
# Mean:  44
# Median:  44
# 0 would fix on first try
# 0 would fix in 3 or fewer tries
# 0 would fix in 10 or fewer tries

# %%
# Fixpoint technique (for timeout) performs worse on Verus, while proof_count technique (for fast_unknown) performs about the same on verus
from benchmark_consts import *
timeout_ranks = summaries[TraceFailure.TIMEOUT]
total_ranks = timeout_ranks + fast_unknown_results + slow_unknown_results
ranks = np.array(total_ranks)

print(total_ranks)

print("CUMULATIVE",len(UNSTABLE_VERUS))
# print("mean: ", mean(total_ranks))
# print("median: ", median(total_ranks))
print(np.where(ranks == 1)[0].shape[0], "would fix on first try")
print(np.where(ranks <= 3)[0].shape[0], "would fix in 3 or fewer tries")
print(np.where(ranks <= 10)[0].shape[0], "would fix in 10 or fewer tries")
print(f"We solve {(np.where(ranks <= 10)[0].shape[0] /len(UNSTABLE_VERUS)) * 100}% of the queries with the top 10 quantifiers!")
# Out:
# [1, 1, 3, 326, 12, 1, 74, 1, 1, 1, 3, 1, 5, 5, 1, 7, 2, 2, 66, 5, 11, 18, 64, 1, 7, 3, 13, 2, 1, 799, 288, 57, 3, 2, 21, 35, 9, 6, 6, 20, 5, 7, 3, 3, 9, 19, 8, 5, 2, 8, 2, 31, 3, 7, 14, 4, 4, 4, 5, 9, 43, 1, 44]
# CUMULATIVE 70
# 11 would fix on first try
# 24 would fix in 3 or fewer tries
# 44 would fix in 10 or fewer tries
# We solve 62.857142857142854% of the queries with the top 10 quantifiers!
