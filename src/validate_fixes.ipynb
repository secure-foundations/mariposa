# %%
"""
A script to validate query fixes (i.e. do the fixes actually result in stable queries).
"""
import os
import sys

original_cwd = os.getcwd()
print(original_cwd)

sys.path.append("/home/yizhou7/mariposa/src")
os.chdir("/home/yizhou7/mariposa/")

import numpy as np
from statistics import mean, median
import pandas as pd
from pathlib import Path
import glob
import matplotlib.pyplot as plt

from debugger.proof_analyzer import ProofAnalyzer
from evaluator import Evaluator

from base.solver import RCode
from debugger.debugger import debugger3
from enum import Enum

from utils.analysis_utils import Categorizer

# set this to true if I need to move folders over and set up a proj
move_folders = False
# Out:
# /home/amarshah/mariposa/src

# %%
finished = ["f986501402", "b546a78766", "2a3b1202bd", "1b7f64e95b", "72d4708532", "36a1859f27", "243ec915e0", "c1a05b62ba", "0b346d0f87", "83448eecf5", "1d57b073cc", "fae7756eb4", "72a2c42fee", "4d7e86f7da", "38d93c5774", "d27df8e3bb", "7fedd43bf6", "7373c499e2", "915d51eada", "4819fafc3f", "203627efb4", "d1b83603db", "6bbd2c848c", "61daeac2cb", "d0c54edf56", "c8ca6d3f20", "8e8d83f571", "e6d6347750", "543c83b4e6", "d87c685738", "e695dc7eeb", "4dc3312a9a", "018a6d3a64", "1bcd3aa5cb", "59dd7b549d", "6a7bc24676", "fb0072addd", "b6f117b674", "9c17013417", "7798796cc9", "3b1c756824", "3818823b0a", "70b04e001b", "a027d8f301", "2ead327dad", "60095b1a59", "9415956048", "2298e56311", "1673ca97a5", "4eec50bfef", "676f102c30", "8852397c03", "c8f75a1321", "c4b6442111", "b5b0f8c2f2", "40d72d4071", "c4350a29e0", "868d0bf364", "28b317196a", "2072de2763", "c83a6af781", "fa733ab6d6", "24a1fea1cb", "77448147c2", "3ab530aac4", "0defc27a3b", "6737d567f9", "83c57f0bcb", "17b0b45c82", "298f3245ca", "5741fd7355", "2f7324b043", "3b176b0694", "d82f76226c", "c3e7d9e76e", "f6fde2cf65", "2ba7cc6a6a", "b182e2a043", "975f2fa60e", "0b497bc090", "c066e22df7", "b8ed14e0c5", "a9102fb49c", "28f9cbda22", "b96ad66775", "3c3d86031e", "ea5023bb77", "31e9d7c601", "6b83ccf507", "ae3b449b81", "667b2b80fe", "d8fb40a98b", "caebe30494", "5954cb98c8", "f92fbc3fec", "cd6cdb377d", "0e3ac592f3", "4399a84f2c", "e41d0ee45e", "1a397d663b", "179f62e2d4", "ab307c9008", "411ef2f9db", "03df204fcd", "1a4c83bd83", "383f10cfb6", "2489279611", "a6e96b148b", "06a10772cf", "a0c42cc37e", "a2998ce7e3", "d8c62df78c", "af3454b9b7", "cdfc45fd41", "8031fd6ec8", "d3b07a4fd8", "a70ef5a023", "416446ca74", "b8265691e7", "74193764bc", "adb0c59b26", "2362f78e4b", "ed36496079", "47c0fbf175", "3ce5c5e4dc", "6884529c21", "782b28a40e", "ef1ebd5d7d", "b6123843b3", "a4cb7288c6", "ffb00a9e92", "cc5b8bed53", "c7dd9386ea", "751af
5", "f5dc6f777b", "e1c4753770", "62e586cacd", "b3ec86d7f1", "0ad8073737", "fb2ca1a594", "9735a6b051", "31258859ac", "e9080f3e47", "1ab6690346", "49665b0459", "1752022f42", "9b9e796545", "91f1dee2f1", "db5b85130e", "e65b46b51f", "0ef92feb14", "9796f7a39f", "50b414ceb9", "7dccaece2d", "11e4bbf583", "ed978bf127", "4aecdc3251", "8cd183cebe", "4ae002e825", "3ed37733c3", "53b94c898b", "1d23e345a5", "39c8cf4676", "ce3b53d3eb", "158af610a6", "93c0449639", "112938db3c", "90270fc66a", "94bc3cfd5f", "7e492ef45f", "a19f4272bf", "125461812b", "8a59d4481f", "81df0e63de", "f8271123d9", "842038cbbb", "557e72f7ae", "c174525f75", "2f80d5bcaa", "790839853f", "2606c5a287", "d29cd9f10a", "ac4102a2e0", "7d2782e41a", "f7f46a3a04", "a854e6c8ad", "712b931174", "eec60fd21e", "22188d7780", "1fc9b21323", "f9f9100cfb", "10b27f0984", "9b55212ceb", "61fbd4977f", "4680269ef1", "c5b6c95d49", "473fa6f229", "1c167aafa9", "3ac32afb30", "b920f021f6", "5add81d45d", "fa548b2af5", "167389a8ef", "519fdc89c1", "fbd113c34b", "5b7d18ab3e", "a650f4205b", "a5dd7919bb", "3c8b9dae45", "17904af761", "6f6c55d971", "0556ae8c88"]

# %%
class TraceFailure(Enum):
    TIMEOUT = "timeout"
    SLOW_UNKNOWN = "slow_unknown"
    FAST_UNKNOWN = "fast_unknown"
    NOT_FAIL = "did not fail"
    
f_modes = Categorizer()

for f in fixable:
    dbg = debugger3("dbg/" + f)
    mi = dbg.get_trace_info()
    rtime = mi.trace_time/1000

    assert mi.trace_rcode != RCode.ERROR

    if mi.trace_rcode == RCode.TIMEOUT:
        reason = TraceFailure.TIMEOUT
    elif rtime >= 10:
        reason = TraceFailure.TIMEOUT
    elif mi.trace_rcode == RCode.UNSAT:
        reason = TraceFailure.NOT_FAIL # ???
    else:
        (mi.trace_rcode, rtime)
        assert mi.trace_rcode == RCode.UNKNOWN
        if rtime <= 4:
            reason = TraceFailure.FAST_UNKNOWN
        else:
            reason = TraceFailure.SLOW_UNKNOWN

    f_modes.add_item(reason, f)
# Out:
# [INFO] [init] resolved to data/projs/bench_unstable/base.z3/d_lvbkv--BlockCacheSystem-BlockSystem.i.dfy.Impl__BlockSystem.__default.FreezeStepPreservesGraphs.smt2
# [INFO] [init] dbg root: dbg/f986501402/
# [INFO] [init] resolved to data/projs/bench_unstable/base.z3/d_komodo--verified-sha-hmac.gen.dfyImpl___module.__default.va__lemma__hmac__inner.smt2
# [INFO] [init] dbg root: dbg/b546a78766/
# [INFO] [init] resolved to data/projs/bench_unstable/base.z3/d_komodo--verified-attest_helpers.gen.dfyImpl___module.__default.va__lemma__zero__pad__memory.smt2
# [INFO] [init] dbg root: dbg/1b7f64e95b/
# [INFO] [init] resolved to data/projs/bench_unstable/base.z3/d_lvbkv--ByteBlockCacheSystem-Marshalling.i.dfy.Impl__Marshalling.__default.pivotTableWeightUpperBound.smt2
# [INFO] [init] dbg root: dbg/72d4708532/
# [INFO] [init] resolved to data/projs/bench_unstable/base.z3/d_lvbkv--lib-Marshalling-Seqs.i.dfy.Impl__Collections____Seqs__i.__default.lemma__SeqCatRev__adds.smt2
# ...

# %%
f_modes.finalize()
f_modes.print_status()
# Out:
# | category                  |   count | percentage   |
# |---------------------------|---------|--------------|
# | TraceFailure.TIMEOUT      |     299 | 79.73 %      |
# | TraceFailure.FAST_UNKNOWN |      66 | 17.6 %       |
# | TraceFailure.NOT_FAIL     |       8 | 2.13 %       |
# | TraceFailure.SLOW_UNKNOWN |       2 | 0.53 %       |
# | total                     |     375 | 100.00 %     |

# %%
fast_unknown_files = ["../cache/" + f + ".report" for f in f_modes[TraceFailure.FAST_UNKNOWN]]
timeout_files = ["../cache/" + f + ".report" for f in f_modes[TraceFailure.TIMEOUT]]
slow_unknown_files = ["../cache/" + f + ".report" for f in f_modes[TraceFailure.SLOW_UNKNOWN]]
not_fail_files = ["../cache/" + f + ".report" for f in f_modes[TraceFailure.NOT_FAIL]]

# %%
from utils.cache_utils import load_cache


def process_queries(files):
    stabilizing_edits = []
    for file in files:
        report = load_cache(file)
        stabilizing_edits += report.stabilized['edit_path'].to_list()
    return stabilizing_edits


fast_unknown_edits = process_queries(fast_unknown_files)
timeout_edits = process_queries(timeout_files)
slow_unknown_edits = process_queries(slow_unknown_files)
not_fail_edits = process_queries(not_fail_files)
print(slow_unknown_edits)
# Out:
# ['data/projs/singleton_e998d08b31/base.z3/297754be.smt2', 'data/projs/singleton_e998d08b31/base.z3/57020274.smt2', 'data/projs/singleton_e998d08b31/base.z3/9284ec66.smt2', 'data/projs/singleton_e998d08b31/base.z3/c64cf64a.smt2', 'data/projs/singleton_3ce5c5e4dc/base.z3/0074d8de.smt2', 'data/projs/singleton_3ce5c5e4dc/base.z3/05da2752.smt2', 'data/projs/singleton_3ce5c5e4dc/base.z3/097b2af7.smt2', 'data/projs/singleton_3ce5c5e4dc/base.z3/0b2a8971.smt2', 'data/projs/singleton_3ce5c5e4dc/base.z3/0bab5c06.smt2', 'data/projs/singleton_3ce5c5e4dc/base.z3/20026e8a.smt2', 'data/projs/singleton_3ce5c5e4dc/base.z3/2382d58a.smt2', 'data/projs/singleton_3ce5c5e4dc/base.z3/2a93549b.smt2', 'data/projs/singleton_3ce5c5e4dc/base.z3/31366bc2.smt2', 'data/projs/singleton_3ce5c5e4dc/base.z3/317f1ef5.smt2', 'data/projs/singleton_3ce5c5e4dc/base.z3/371b6885.smt2', 'data/projs/singleton_3ce5c5e4dc/base.z3/37c4678f.smt2', 'data/projs/singleton_3ce5c5e4dc/base.z3/39ddf555.smt2', 'data/projs/singleton_3ce5c5
# ...

# %%
import shutil
import os

os.chdir(original_cwd)
print(os.getcwd())

# Define source and target paths
source_dir = "/home/yizhou7/mariposa/"
target_base = "/home/amarshah/mariposa/data/samples"
# target_base = os.getcwd() + "../data/samples/"

# Define mapping of list names to target folders
edit_groups = {
    "fast_unknown": fast_unknown_edits,
    "timeout": timeout_edits,
    "slow_unknown": slow_unknown_edits,
    "not_fail": not_fail_edits,
}

if move_folders:

    # Move files to the respective base.z3/ folders
    for category, file_list in edit_groups.items():
        target_dir = os.path.join(target_base, f"mariposa_{category}_proj")
        os.makedirs(target_dir, exist_ok=True) 

        for file_name in file_list:
            src = os.path.join(source_dir, file_name)

            # Strip everything before and including the last "/"
            dest_file_name = os.path.basename(file_name)
            dest = os.path.join(target_dir, dest_file_name)

            try:
                if os.path.exists(dest):
                    os.remove(dest)  # Remove existing file before moving
                shutil.copy(src, dest)
                print(f"Moved {src} → {dest}")
            except Exception as e:
                print(f"Error moving {src}: {e}")
# Out:
# /home/amarshah/mariposa/src

# %%
# List of project names
names = ["mariposa_timeout", "mariposa_not_fail"] #["mariposa_fast_unknown", "mariposa_slow_unknown"]

if move_folders:
    # Run the commands
    for name in names:
        command = ["./src/proj_wizard.py", "create", "-i", f"data/samples/{name}_proj", "--new-project-name", name]
        subprocess.run(command, check=True)

# %%
# Running Mariposa on the fast_unknown. Can start here if the project has already been built
import subprocess

os.chdir(original_cwd)
# Move to parent directory
parent_dir = os.path.abspath("..")  # Get absolute path of the parent directory
os.chdir(parent_dir)  # Change working directory

# Get query_paths function
def get_query_paths(process):
    query_files = []

    # Read output line by line
    for line in iter(process.stdout.readline, ''):
        print(line, end='')  # Print to terminal
        if line[:11] == "query path:":
            file_name = line.split("query path:")[1].strip()
            query_files.append(file_name)

    process.stdout.close()
    process.wait()
    return query_files




command = ["./src/exper_wizard.py", "multiple", "-i", "data/projs/mariposa_fast_unknown/base.z3/", "-e", "default", "--category-verbosity", "3"]
process = subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

mariposa_fast_unknown_query_files = get_query_paths(process)
print(mariposa_fast_unknown_query_files)
# Out:
# [WARN] experiment results already exists for data/projs/mariposa_fast_unknown/base.z3
# === Overall Report ===
#
# project dir:	data/projs/mariposa_fast_unknown/base.z3
# exper config:	debug
# solver path:	bin/z3-4.13.0
# analyzer:	default
#
# | category   |   count | percentage   |
# |------------|---------|--------------|
# | stable     |     558 | 86.92 %      |
# | unstable   |      84 | 13.08 %      |
# | total      |     642 | 100.00 %     |
#
# === unstable (1/84) ===
# query path: data/projs/mariposa_fast_unknown/base.z3/1ef2f439.smt2
#
# main failure type:	mostly_unknown
#
# === unstable (2/84) ===
# query path: data/projs/mariposa_fast_unknown/base.z3/8b0c3fbd.smt2
#
# main failure type:	mostly_unknown
#
# === unstable (3/84) ===
# query path: data/projs/mariposa_fast_unknown/base.z3/b8ed0bd1.smt2
#
# main failure type:	mostly_timeout
#
# === unstable (4/84) ===
# query path: data/projs/mariposa_fast_unknown/base.z3/f9b5d030.smt2
#
# main failure type:	mostly_unknown
#
# ...

# %%
command = ["./src/exper_wizard.py", "multiple", "-i", "data/projs/mariposa_timeout/base.z3/", "-e", "default", "--category-verbosity", "3"]
process = subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

mariposa_timeout_query_files = get_query_paths(process)
print(mariposa_timeout_query_files)





# will probably run this in a screen
# Out:
# [WARN] experiment results already exists for data/projs/mariposa_timeout/base.z3
# === Overall Report ===
#
# project dir:	data/projs/mariposa_timeout/base.z3
# exper config:	debug
# solver path:	bin/z3-4.13.0
# analyzer:	default
#
# | category   |   count | percentage   |
# |------------|---------|--------------|
# | stable     |    1736 | 89.39 %      |
# | unstable   |     206 | 10.61 %      |
# | total      |    1942 | 100.00 %     |
#
# === unstable (1/206) ===
# query path: data/projs/mariposa_timeout/base.z3/8694a2d3.smt2
#
# main failure type:	mostly_timeout
#
# === unstable (2/206) ===
# query path: data/projs/mariposa_timeout/base.z3/c78784af.smt2
#
# main failure type:	mostly_unknown
#
# === unstable (3/206) ===
# query path: data/projs/mariposa_timeout/base.z3/396bf25c.smt2
#
# main failure type:	mostly_unknown
#
# === unstable (4/206) ===
# query path: data/projs/mariposa_timeout/base.z3/6cbda1b7.smt2
#
# main failure type:	mostly_timeout
#
# === unstable (5/206) ===
# ...

# %%
command = ["./src/exper_wizard.py", "multiple", "-i", "data/projs/mariposa_not_fail/base.z3/", "-e", "default", "--category-verbosity", "3"]
# subprocess.run(command, check=True)

# Run the process and capture output
process = subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

mariposa_not_fail_query_files = get_query_paths(process)

print("The query files are:", mariposa_not_fail_query_files)
# Out:
# [WARN] experiment results already exists for data/projs/mariposa_not_fail/base.z3
# === Overall Report ===
#
# project dir:	data/projs/mariposa_not_fail/base.z3
# exper config:	debug
# solver path:	bin/z3-4.13.0
# analyzer:	default
#
# | category   |   count | percentage   |
# |------------|---------|--------------|
# | stable     |     667 | 92.9 %       |
# | unstable   |      51 | 7.1 %        |
# | total      |     718 | 100.00 %     |
#
# === unstable (1/51) ===
# query path: data/projs/mariposa_not_fail/base.z3/51156c83.smt2
#
# main failure type:	mostly_unknown
#
# === unstable (2/51) ===
# query path: data/projs/mariposa_not_fail/base.z3/b8d887fe.smt2
#
# main failure type:	mostly_timeout
#
# === unstable (3/51) ===
# query path: data/projs/mariposa_not_fail/base.z3/8aeca466.smt2
#
# main failure type:	mostly_timeout
#
# === unstable (4/51) ===
# query path: data/projs/mariposa_not_fail/base.z3/edeb6e43.smt2
#
# main failure type:	mostly_unknown
#
# === unstable (5/51) ===
# ...

# %%
command = ["./src/exper_wizard.py", "multiple", "-i", "data/projs/mariposa_slow_unknown/base.z3/", "-e", "default", "--category-verbosity", "3"]
# subprocess.run(command, check=True)

# Run the process and capture output
process = subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

mariposa_slow_unknown_query_files = get_query_paths(process)

print("The query files are:", mariposa_slow_unknown_query_files)
# Out:
# [WARN] experiment results already exists for data/projs/mariposa_slow_unknown/base.z3
# === Overall Report ===
#
# project dir:	data/projs/mariposa_slow_unknown/base.z3
# exper config:	debug
# solver path:	bin/z3-4.13.0
# analyzer:	default
#
# | category   |   count | percentage   |
# |------------|---------|--------------|
# | stable     |      55 | 94.83 %      |
# | unstable   |       3 | 5.17 %       |
# | total      |      58 | 100.00 %     |
#
# === unstable (1/3) ===
# query path: data/projs/mariposa_slow_unknown/base.z3/6077b7d9.smt2
#
# main failure type:	mostly_unknown
#
# === unstable (2/3) ===
# query path: data/projs/mariposa_slow_unknown/base.z3/39ddf555.smt2
#
# main failure type:	mostly_unknown
#
# === unstable (3/3) ===
# query path: data/projs/mariposa_slow_unknown/base.z3/e8f033ea.smt2
#
# main failure type:	mostly_unknown
#
#
# === Report End ===
# ...
